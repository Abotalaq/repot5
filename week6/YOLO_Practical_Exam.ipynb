# %% [markdown]
# # Road Traffic Vehicle Counting Exam

# %% [markdown]
# In this exam, you will use the YOLO (You Only Look Once) object detection model to analyze a video of road traffic. Your primary task is to count the number of vehicles exiting the road at each of the four exits (located at the top, bottom, left, and right of the frame). The video for this task is provided at `Datasets/YOLO_Exam_Video.mp4`.
#
# ## Objectives
# - Load and process the video using OpenCV.
# - Utilize the YOLO model to detect vehicles in each frame.
# - Manipulate the video frames using OpenCV.
# - Track vehicles as they move across the video frames.
# - Count the number of vehicles exiting via the top street.
# - Count the number of vehicles exiting via the bottom street.
# - Count the number of vehicles exiting via the left street.
# - Count the number of vehicles exiting via the right street.

# %% [markdown]
# ## Setup Environment

# %% [markdown]
# Before you begin, ensure you have the necessary libraries installed. You will need `opencv`, and `ultralytics` among others.
# If these are not installed, you should install them.

# %%
# prompt: library opencv

# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/anaconda3/lib/python3.11/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/lib/python3.11/site-packages (from opencv-python) (1.26.4)

# %%
# !pip install ultralytics
# !pip install opencv-p
# Out:
# Requirement already satisfied: ultralytics in /opt/anaconda3/lib/python3.11/site-packages (8.2.85)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.4.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (0.19.0)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2024.7.4)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2023.10.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# ERROR: Could not find a version that satisfies the requirement opencv-p (from versions: none)
# ERROR: No matching distribution found for opencv-p

# %% [markdown]
# ## Load the YOLO Model

# %% [markdown]
# You will first need to load the YOLO model, there is a custom model for this exam called `YOLO_Model.pt` under Datasets file ⚠️ PLEASE USE THIS MODEL AND DO NOT USE ANY OTHER MODEL ⚠️.
# Write the code to load the YOLO model below:

# %%
import cv2

from ultralytics import YOLO, solutions

model = YOLO("/Users/abd/Downloads/week 6 exam/YOLO_Model.pt")

# %% [markdown]
# ## Prepare the Video Capture

# %% [markdown]
# Create a variable to capture the video frames, you can use `cv2.VideoCapture()` to achive this.

# %%
cap = cv2.VideoCapture("/Users/abd/Downloads/week 6 exam/YOLO_Video.mp4")
assert cap.isOpened(), "Error reading video file"

# %% [markdown]
# ## Get Video Information

# %% [markdown]
# You can use `cv2` library to get these information fro the `VideoCapture()` variable you created to extract these information:
# * `height`: Video's height.
# * `width`: Video's width.
# * `fps`: Video's frames.

# %%
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# %%
print(w)
print(h)
print(fps)
# Out:
# 1920
# 1080
# 29

# %% [markdown]
# ## Prepare Video Writer to Store the Output

# %% [markdown]
# Create a variable that uses `cv2.VideoCapture()` to save the video with the bounding boxes, specified Region of Interest rectangle (ROI) and the counted vehicles on each sides. You will need to make the video with the same `fps`, `width`, `height`, and specify the codec and output path of the video.

# %%
video_writer = cv2.VideoWriter("object_counting_output.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# %% [markdown]
# ## Expermint to get the `(x1, y1, x2, y2)` of the ROI

# %% [markdown]
# ### Hint
# When defining the Regions of Interest (ROIs) for detecting vehicles exiting the road, consider the coordinates that outline the relevant areas. These coordinates can be specified as `(x1, y1, x2, y2)`, where `(x1, y1)` is the top-left corner and `(x2, y2)` is the bottom-right corner of the rectangle.
#
# Experiment with different coordinates to accurately cover the streets where vehicles exit. Visualize these ROIs by drawing rectangles on a frame of the video and adjust the coordinates as needed until you capture the desired areas effectively.

# %%
region_points = [(0, 1080), (1920,1080),(1920, 0),(0,0)] #drowing a rectangle on the whole video just to make sure


# Init Object Counter
counter = solutions.ObjectCounter(
    view_img=True,
    reg_pts=region_points,
    names=model.names,
    draw_tracks=True,
    line_thickness=2,
)

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    tracks = model.track(im0, persist=True, show=False)

    im0 = counter.start_counting(im0, tracks)
    video_writer.write(im0)

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# Polygon Counter Initiated.
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 5 vans, 218.7ms
# Speed: 1.8ms preprocess, 218.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 207.6ms
# Speed: 1.2ms preprocess, 207.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 234.1ms
# Speed: 1.8ms preprocess, 234.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 93 cars, 1 truck, 3 vans, 253.5ms
# Speed: 1.4ms preprocess, 253.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 3 vans, 253.5ms
# Speed: 1.2ms preprocess, 253.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 197.4ms
# Speed: 1.5ms preprocess, 197.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 3 vans, 211.6ms
# Speed: 1.1ms preprocess, 211.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 209.3ms
# Speed: 1.1ms preprocess, 209.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 197.0ms
# Speed: 1.1ms preprocess, 197.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 3 vans, 197.4ms
# Speed: 1.4ms preprocess, 197.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 3 vans, 204.1ms
# Speed: 1.1ms preprocess, 204.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 3 vans, 198.0ms
# Speed: 1.1ms preprocess, 198.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 5 vans, 194.0ms
# Speed: 1.2ms preprocess, 194.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 3 vans, 196.0ms
# Speed: 1.3ms preprocess, 196.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 3 vans, 193.7ms
# Speed: 1.2ms preprocess, 193.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 194.8ms
# Speed: 1.4ms preprocess, 194.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 195.5ms
# Speed: 1.1ms preprocess, 195.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 3 vans, 194.0ms
# Speed: 1.1ms preprocess, 194.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 3 vans, 200.6ms
# Speed: 1.2ms preprocess, 200.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 195.1ms
# Speed: 1.1ms preprocess, 195.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 194.4ms
# Speed: 1.2ms preprocess, 194.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 192.9ms
# Speed: 1.3ms preprocess, 192.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 197.0ms
# Speed: 1.1ms preprocess, 197.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 198.2ms
# Speed: 1.1ms preprocess, 198.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 205.0ms
# Speed: 1.6ms preprocess, 205.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 196.8ms
# Speed: 1.2ms preprocess, 196.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 200.9ms
# Speed: 1.2ms preprocess, 200.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 200.2ms
# Speed: 1.4ms preprocess, 200.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 194.6ms
# Speed: 1.4ms preprocess, 194.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 196.0ms
# Speed: 1.1ms preprocess, 196.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 5 vans, 202.5ms
# Speed: 1.1ms preprocess, 202.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 194.2ms
# Speed: 1.1ms preprocess, 194.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 5 vans, 195.9ms
# Speed: 1.3ms preprocess, 195.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 192.7ms
# Speed: 1.1ms preprocess, 192.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 193.2ms
# Speed: 1.4ms preprocess, 193.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 193.8ms
# Speed: 1.2ms preprocess, 193.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 5 vans, 192.1ms
# Speed: 1.2ms preprocess, 192.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 5 vans, 200.0ms
# Speed: 1.4ms preprocess, 200.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 198.0ms
# Speed: 1.1ms preprocess, 198.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 3 vans, 199.7ms
# Speed: 1.5ms preprocess, 199.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 196.7ms
# Speed: 1.1ms preprocess, 196.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 5 vans, 196.7ms
# Speed: 1.1ms preprocess, 196.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 5 vans, 193.6ms
# Speed: 1.4ms preprocess, 193.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 5 vans, 195.6ms
# Speed: 1.3ms preprocess, 195.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 194.2ms
# Speed: 1.4ms preprocess, 194.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 191.9ms
# Speed: 1.1ms preprocess, 191.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 196.6ms
# Speed: 3.3ms preprocess, 196.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 192.6ms
# Speed: 1.0ms preprocess, 192.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 194.8ms
# Speed: 1.4ms preprocess, 194.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 194.6ms
# Speed: 1.3ms preprocess, 194.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 4 vans, 195.7ms
# Speed: 1.1ms preprocess, 195.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 199.5ms
# Speed: 1.1ms preprocess, 199.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 194.9ms
# Speed: 1.5ms preprocess, 194.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 5 vans, 195.3ms
# Speed: 1.3ms preprocess, 195.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 5 vans, 193.8ms
# Speed: 1.1ms preprocess, 193.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 3 vans, 191.8ms
# Speed: 1.5ms preprocess, 191.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 3 vans, 193.3ms
# Speed: 1.1ms preprocess, 193.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 193.6ms
# Speed: 1.3ms preprocess, 193.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 192.8ms
# Speed: 1.1ms preprocess, 192.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 198.2ms
# Speed: 1.1ms preprocess, 198.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 212.5ms
# Speed: 2.7ms preprocess, 212.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 188.6ms
# Speed: 1.1ms preprocess, 188.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 191.1ms
# Speed: 1.2ms preprocess, 191.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 192.0ms
# Speed: 1.3ms preprocess, 192.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 195.8ms
# Speed: 1.0ms preprocess, 195.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 197.6ms
# Speed: 1.5ms preprocess, 197.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 197.8ms
# Speed: 1.1ms preprocess, 197.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 198.2ms
# Speed: 1.1ms preprocess, 198.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 3 vans, 195.9ms
# Speed: 1.3ms preprocess, 195.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 3 vans, 195.1ms
# Speed: 1.1ms preprocess, 195.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 195.2ms
# Speed: 1.2ms preprocess, 195.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 193.3ms
# Speed: 1.1ms preprocess, 193.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 192.4ms
# Speed: 1.1ms preprocess, 192.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 241.8ms
# Speed: 1.1ms preprocess, 241.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 208.0ms
# Speed: 1.2ms preprocess, 208.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 200.1ms
# Speed: 1.2ms preprocess, 200.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 196.0ms
# Speed: 1.3ms preprocess, 196.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 221.6ms
# Speed: 1.1ms preprocess, 221.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 4 vans, 278.2ms
# Speed: 1.6ms preprocess, 278.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 4 vans, 234.8ms
# Speed: 1.2ms preprocess, 234.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 4 vans, 232.9ms
# Speed: 1.3ms preprocess, 232.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 4 vans, 224.8ms
# Speed: 1.4ms preprocess, 224.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 4 vans, 208.9ms
# Speed: 1.2ms preprocess, 208.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 97 cars, 1 truck, 3 vans, 280.0ms
# Speed: 1.8ms preprocess, 280.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 97 cars, 1 truck, 3 vans, 257.2ms
# Speed: 2.6ms preprocess, 257.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 332.0ms
# Speed: 1.3ms preprocess, 332.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 247.5ms
# Speed: 6.6ms preprocess, 247.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 210.6ms
# Speed: 2.6ms preprocess, 210.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 206.9ms
# Speed: 1.1ms preprocess, 206.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 213.2ms
# Speed: 1.1ms preprocess, 213.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 209.7ms
# Speed: 1.9ms preprocess, 209.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 222.6ms
# Speed: 1.4ms preprocess, 222.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 201.0ms
# Speed: 1.2ms preprocess, 201.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 205.8ms
# Speed: 1.1ms preprocess, 205.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 216.3ms
# Speed: 1.4ms preprocess, 216.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 97 cars, 1 truck, 2 vans, 205.6ms
# Speed: 1.8ms preprocess, 205.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 98 cars, 2 vans, 207.0ms
# Speed: 1.2ms preprocess, 207.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 97 cars, 2 vans, 203.0ms
# Speed: 1.1ms preprocess, 203.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 98 cars, 2 vans, 194.5ms
# Speed: 1.4ms preprocess, 194.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 97 cars, 1 truck, 2 vans, 221.6ms
# Speed: 1.2ms preprocess, 221.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 194.9ms
# Speed: 1.1ms preprocess, 194.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 199.4ms
# Speed: 1.4ms preprocess, 199.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 206.0ms
# Speed: 1.2ms preprocess, 206.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 204.2ms
# Speed: 1.2ms preprocess, 204.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 204.7ms
# Speed: 1.1ms preprocess, 204.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 199.5ms
# Speed: 1.3ms preprocess, 199.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 200.8ms
# Speed: 1.4ms preprocess, 200.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 198.6ms
# Speed: 1.2ms preprocess, 198.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 197.9ms
# Speed: 1.3ms preprocess, 197.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 199.1ms
# Speed: 1.1ms preprocess, 199.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 194.7ms
# Speed: 1.1ms preprocess, 194.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 196.9ms
# Speed: 1.1ms preprocess, 196.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 5 vans, 198.1ms
# Speed: 1.3ms preprocess, 198.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 192.3ms
# Speed: 1.1ms preprocess, 192.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 195.5ms
# Speed: 1.5ms preprocess, 195.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 201.0ms
# Speed: 1.1ms preprocess, 201.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 204.8ms
# Speed: 1.2ms preprocess, 204.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 203.3ms
# Speed: 1.1ms preprocess, 203.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 210.5ms
# Speed: 1.3ms preprocess, 210.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 3 vans, 201.8ms
# Speed: 2.2ms preprocess, 201.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 199.7ms
# Speed: 1.5ms preprocess, 199.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 3 vans, 221.1ms
# Speed: 1.1ms preprocess, 221.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 3 vans, 202.7ms
# Speed: 1.1ms preprocess, 202.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 3 vans, 196.6ms
# Speed: 1.1ms preprocess, 196.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 3 vans, 195.8ms
# Speed: 1.1ms preprocess, 195.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 196.2ms
# Speed: 1.1ms preprocess, 196.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 5 vans, 196.5ms
# Speed: 1.2ms preprocess, 196.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 194.3ms
# Speed: 1.1ms preprocess, 194.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 197.0ms
# Speed: 1.3ms preprocess, 197.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 5 vans, 200.0ms
# Speed: 1.5ms preprocess, 200.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 5 vans, 200.8ms
# Speed: 1.2ms preprocess, 200.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 5 vans, 204.1ms
# Speed: 1.5ms preprocess, 204.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 199.1ms
# Speed: 1.5ms preprocess, 199.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 96 cars, 1 truck, 3 vans, 197.9ms
# Speed: 1.5ms preprocess, 197.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 95 cars, 1 truck, 3 vans, 197.9ms
# Speed: 1.1ms preprocess, 197.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 200.8ms
# Speed: 1.3ms preprocess, 200.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 5 vans, 285.7ms
# Speed: 1.5ms preprocess, 285.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 352.6ms
# Speed: 3.3ms preprocess, 352.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 236.9ms
# Speed: 1.1ms preprocess, 236.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 4 vans, 243.7ms
# Speed: 1.6ms preprocess, 243.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 223.8ms
# Speed: 1.1ms preprocess, 223.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 5 vans, 213.6ms
# Speed: 1.1ms preprocess, 213.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 199.8ms
# Speed: 1.1ms preprocess, 199.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 205.1ms
# Speed: 1.5ms preprocess, 205.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 5 vans, 221.0ms
# Speed: 1.3ms preprocess, 221.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 93 cars, 1 truck, 4 vans, 198.5ms
# Speed: 1.2ms preprocess, 198.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 5 vans, 200.3ms
# Speed: 1.6ms preprocess, 200.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 5 vans, 200.6ms
# Speed: 1.2ms preprocess, 200.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 5 vans, 195.0ms
# Speed: 1.4ms preprocess, 195.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 5 vans, 194.5ms
# Speed: 1.1ms preprocess, 194.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 5 vans, 196.5ms
# Speed: 1.1ms preprocess, 196.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 194.3ms
# Speed: 1.1ms preprocess, 194.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 5 vans, 197.6ms
# Speed: 1.1ms preprocess, 197.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 5 vans, 196.6ms
# Speed: 1.0ms preprocess, 196.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 5 vans, 199.0ms
# Speed: 1.1ms preprocess, 199.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 5 vans, 199.9ms
# Speed: 1.5ms preprocess, 199.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 200.8ms
# Speed: 1.5ms preprocess, 200.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 203.0ms
# Speed: 1.5ms preprocess, 203.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 5 vans, 202.8ms
# Speed: 1.4ms preprocess, 202.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 5 vans, 200.7ms
# Speed: 1.4ms preprocess, 200.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 199.9ms
# Speed: 1.4ms preprocess, 199.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 202.6ms
# Speed: 1.3ms preprocess, 202.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 195.5ms
# Speed: 1.4ms preprocess, 195.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 198.0ms
# Speed: 1.1ms preprocess, 198.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 197.4ms
# Speed: 1.1ms preprocess, 197.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 5 vans, 200.0ms
# Speed: 1.1ms preprocess, 200.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 4 vans, 197.5ms
# Speed: 1.2ms preprocess, 197.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 4 vans, 196.9ms
# Speed: 1.2ms preprocess, 196.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 4 vans, 201.9ms
# Speed: 1.3ms preprocess, 201.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 197.0ms
# Speed: 1.2ms preprocess, 197.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 199.9ms
# Speed: 1.2ms preprocess, 199.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 199.1ms
# Speed: 1.3ms preprocess, 199.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 199.3ms
# Speed: 1.3ms preprocess, 199.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 89 cars, 1 truck, 4 vans, 216.3ms
# Speed: 1.3ms preprocess, 216.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 89 cars, 1 truck, 4 vans, 206.0ms
# Speed: 1.2ms preprocess, 206.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 89 cars, 1 truck, 4 vans, 193.5ms
# Speed: 1.1ms preprocess, 193.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 89 cars, 1 truck, 4 vans, 195.8ms
# Speed: 1.1ms preprocess, 195.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 193.9ms
# Speed: 1.1ms preprocess, 193.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 224.2ms
# Speed: 1.3ms preprocess, 224.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 241.4ms
# Speed: 1.3ms preprocess, 241.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 217.9ms
# Speed: 4.0ms preprocess, 217.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 215.9ms
# Speed: 1.2ms preprocess, 215.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 208.8ms
# Speed: 1.2ms preprocess, 208.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 214.3ms
# Speed: 1.2ms preprocess, 214.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 91 cars, 1 truck, 3 vans, 211.3ms
# Speed: 1.3ms preprocess, 211.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 214.0ms
# Speed: 1.7ms preprocess, 214.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 215.2ms
# Speed: 1.3ms preprocess, 215.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 215.9ms
# Speed: 1.2ms preprocess, 215.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 212.5ms
# Speed: 1.3ms preprocess, 212.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 199.3ms
# Speed: 1.1ms preprocess, 199.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 211.2ms
# Speed: 1.1ms preprocess, 211.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 251.7ms
# Speed: 1.2ms preprocess, 251.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 207.9ms
# Speed: 1.2ms preprocess, 207.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 215.8ms
# Speed: 1.2ms preprocess, 215.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 223.8ms
# Speed: 1.3ms preprocess, 223.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 201.7ms
# Speed: 1.1ms preprocess, 201.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 201.6ms
# Speed: 1.3ms preprocess, 201.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 216.6ms
# Speed: 1.2ms preprocess, 216.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 220.6ms
# Speed: 1.7ms preprocess, 220.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 231.0ms
# Speed: 1.6ms preprocess, 231.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 213.6ms
# Speed: 1.2ms preprocess, 213.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 206.1ms
# Speed: 1.2ms preprocess, 206.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 2 vans, 205.0ms
# Speed: 1.2ms preprocess, 205.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 2 vans, 201.1ms
# Speed: 1.2ms preprocess, 201.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 210.0ms
# Speed: 1.4ms preprocess, 210.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 200.9ms
# Speed: 1.1ms preprocess, 200.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 2 trucks, 3 vans, 212.1ms
# Speed: 1.3ms preprocess, 212.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 201.5ms
# Speed: 1.5ms preprocess, 201.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 217.5ms
# Speed: 1.2ms preprocess, 217.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 201.8ms
# Speed: 1.4ms preprocess, 201.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 91 cars, 1 truck, 3 vans, 199.1ms
# Speed: 1.2ms preprocess, 199.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 215.9ms
# Speed: 1.2ms preprocess, 215.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 214.3ms
# Speed: 1.2ms preprocess, 214.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 196.4ms
# Speed: 1.2ms preprocess, 196.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 201.6ms
# Speed: 1.1ms preprocess, 201.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 199.8ms
# Speed: 1.1ms preprocess, 199.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 199.9ms
# Speed: 1.2ms preprocess, 199.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 2 trucks, 2 vans, 197.7ms
# Speed: 1.1ms preprocess, 197.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 2 trucks, 2 vans, 196.3ms
# Speed: 1.3ms preprocess, 196.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 2 trucks, 2 vans, 227.1ms
# Speed: 1.1ms preprocess, 227.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 2 trucks, 2 vans, 201.6ms
# Speed: 1.1ms preprocess, 201.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 2 trucks, 2 vans, 201.5ms
# Speed: 1.2ms preprocess, 201.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 2 vans, 201.1ms
# Speed: 1.2ms preprocess, 201.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 2 vans, 206.0ms
# Speed: 1.1ms preprocess, 206.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 2 vans, 203.2ms
# Speed: 1.3ms preprocess, 203.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 2 vans, 202.7ms
# Speed: 1.5ms preprocess, 202.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 2 vans, 196.0ms
# Speed: 1.1ms preprocess, 196.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 2 vans, 204.3ms
# Speed: 1.2ms preprocess, 204.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 2 vans, 199.4ms
# Speed: 1.1ms preprocess, 199.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 2 vans, 198.7ms
# Speed: 1.2ms preprocess, 198.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 2 vans, 200.3ms
# Speed: 1.3ms preprocess, 200.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 2 vans, 197.6ms
# Speed: 1.1ms preprocess, 197.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 2 vans, 198.0ms
# Speed: 1.1ms preprocess, 198.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 2 vans, 198.0ms
# Speed: 1.1ms preprocess, 198.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 2 vans, 199.9ms
# Speed: 1.5ms preprocess, 199.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 212.8ms
# Speed: 1.3ms preprocess, 212.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 198.5ms
# Speed: 1.4ms preprocess, 198.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 199.7ms
# Speed: 2.0ms preprocess, 199.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 201.2ms
# Speed: 1.4ms preprocess, 201.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 196.7ms
# Speed: 1.4ms preprocess, 196.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 195.7ms
# Speed: 1.1ms preprocess, 195.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 194.8ms
# Speed: 1.3ms preprocess, 194.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 195.7ms
# Speed: 1.4ms preprocess, 195.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 196.7ms
# Speed: 1.1ms preprocess, 196.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 2 vans, 194.3ms
# Speed: 1.1ms preprocess, 194.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 2 vans, 194.4ms
# Speed: 1.1ms preprocess, 194.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 2 vans, 198.6ms
# Speed: 1.2ms preprocess, 198.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 2 vans, 200.9ms
# Speed: 1.1ms preprocess, 200.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 2 vans, 203.7ms
# Speed: 1.2ms preprocess, 203.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 88 cars, 1 truck, 2 vans, 199.1ms
# Speed: 1.4ms preprocess, 199.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 2 vans, 202.6ms
# Speed: 1.3ms preprocess, 202.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 89 cars, 1 truck, 2 vans, 201.4ms
# Speed: 1.4ms preprocess, 201.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 89 cars, 1 truck, 2 vans, 201.0ms
# Speed: 1.4ms preprocess, 201.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 195.6ms
# Speed: 1.1ms preprocess, 195.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 198.6ms
# Speed: 1.3ms preprocess, 198.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 193.3ms
# Speed: 1.5ms preprocess, 193.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 195.1ms
# Speed: 1.1ms preprocess, 195.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 192.8ms
# Speed: 1.1ms preprocess, 192.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 194.8ms
# Speed: 1.1ms preprocess, 194.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 3 vans, 199.1ms
# Speed: 1.1ms preprocess, 199.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 3 vans, 198.0ms
# Speed: 1.4ms preprocess, 198.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 3 vans, 203.1ms
# Speed: 1.2ms preprocess, 203.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 3 vans, 211.2ms
# Speed: 1.3ms preprocess, 211.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 3 vans, 229.8ms
# Speed: 1.3ms preprocess, 229.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 226.8ms
# Speed: 1.2ms preprocess, 226.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 3 vans, 201.1ms
# Speed: 1.1ms preprocess, 201.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 3 vans, 196.9ms
# Speed: 1.1ms preprocess, 196.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 3 vans, 197.3ms
# Speed: 4.7ms preprocess, 197.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 3 vans, 193.1ms
# Speed: 1.1ms preprocess, 193.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 3 vans, 193.7ms
# Speed: 1.1ms preprocess, 193.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 3 vans, 207.9ms
# Speed: 1.2ms preprocess, 207.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 3 vans, 220.4ms
# Speed: 1.2ms preprocess, 220.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 3 vans, 218.7ms
# Speed: 1.4ms preprocess, 218.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 3 vans, 211.4ms
# Speed: 1.5ms preprocess, 211.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 3 vans, 211.0ms
# Speed: 1.9ms preprocess, 211.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 2 vans, 211.6ms
# Speed: 1.3ms preprocess, 211.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 2 vans, 197.8ms
# Speed: 1.5ms preprocess, 197.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 2 vans, 197.9ms
# Speed: 1.2ms preprocess, 197.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 2 vans, 199.7ms
# Speed: 1.1ms preprocess, 199.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 1 truck, 3 vans, 193.3ms
# Speed: 1.1ms preprocess, 193.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 2 vans, 196.0ms
# Speed: 1.1ms preprocess, 196.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 2 vans, 199.0ms
# Speed: 1.1ms preprocess, 199.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 1 van, 198.2ms
# Speed: 1.1ms preprocess, 198.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 1 van, 195.1ms
# Speed: 1.5ms preprocess, 195.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 89 cars, 1 truck, 1 van, 195.6ms
# Speed: 1.1ms preprocess, 195.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 89 cars, 1 truck, 1 van, 191.8ms
# Speed: 1.1ms preprocess, 191.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 3 trucks, 1 van, 198.2ms
# Speed: 1.2ms preprocess, 198.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 3 trucks, 1 van, 198.2ms
# Speed: 1.3ms preprocess, 198.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 1 van, 199.2ms
# Speed: 1.1ms preprocess, 199.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 1 van, 200.5ms
# Speed: 1.4ms preprocess, 200.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 1 van, 202.8ms
# Speed: 1.1ms preprocess, 202.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 1 van, 197.3ms
# Speed: 1.4ms preprocess, 197.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 1 van, 200.9ms
# Speed: 1.1ms preprocess, 200.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 1 van, 194.2ms
# Speed: 1.1ms preprocess, 194.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 1 van, 214.5ms
# Speed: 1.1ms preprocess, 214.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 1 van, 197.3ms
# Speed: 1.1ms preprocess, 197.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 1 van, 196.7ms
# Speed: 1.2ms preprocess, 196.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 1 van, 195.7ms
# Speed: 1.1ms preprocess, 195.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 1 van, 195.4ms
# Speed: 1.1ms preprocess, 195.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 1 van, 195.1ms
# Speed: 1.1ms preprocess, 195.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 2 vans, 198.0ms
# Speed: 1.1ms preprocess, 198.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 2 vans, 200.1ms
# Speed: 1.4ms preprocess, 200.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 2 vans, 199.9ms
# Speed: 1.2ms preprocess, 199.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 1 van, 200.1ms
# Speed: 1.4ms preprocess, 200.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 1 van, 198.0ms
# Speed: 1.4ms preprocess, 198.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 1 van, 199.3ms
# Speed: 1.1ms preprocess, 199.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 2 vans, 201.0ms
# Speed: 1.3ms preprocess, 201.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 2 vans, 197.4ms
# Speed: 1.2ms preprocess, 197.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 2 vans, 194.1ms
# Speed: 1.1ms preprocess, 194.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 2 vans, 196.0ms
# Speed: 1.1ms preprocess, 196.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 2 vans, 196.0ms
# Speed: 1.3ms preprocess, 196.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 2 trucks, 1 van, 192.7ms
# Speed: 1.5ms preprocess, 192.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 2 vans, 195.4ms
# Speed: 1.1ms preprocess, 195.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 2 vans, 199.3ms
# Speed: 1.1ms preprocess, 199.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 221.8ms
# Speed: 1.1ms preprocess, 221.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 2 vans, 197.8ms
# ...
#
# 0: 384x640 3 buss, 86 cars, 2 trucks, 1 van, 202.1ms
# Speed: 1.3ms preprocess, 202.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 2 trucks, 1 van, 199.0ms
# Speed: 1.2ms preprocess, 199.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 1 van, 202.7ms
# Speed: 1.5ms preprocess, 202.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 1 truck, 1 van, 201.6ms
# Speed: 1.2ms preprocess, 201.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 1 van, 200.4ms
# Speed: 1.2ms preprocess, 200.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 1 van, 194.8ms
# Speed: 1.2ms preprocess, 194.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 1 truck, 1 van, 196.7ms
# Speed: 1.1ms preprocess, 196.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 1 truck, 1 van, 198.7ms
# Speed: 1.1ms preprocess, 198.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 198.3ms
# Speed: 1.1ms preprocess, 198.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 193.6ms
# Speed: 1.1ms preprocess, 193.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 88 cars, 1 truck, 194.9ms
# Speed: 1.1ms preprocess, 194.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 87 cars, 1 truck, 204.8ms
# Speed: 1.1ms preprocess, 204.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 87 cars, 1 truck, 200.8ms
# Speed: 1.5ms preprocess, 200.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 88 cars, 1 truck, 196.5ms
# Speed: 1.5ms preprocess, 196.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 88 cars, 1 truck, 200.8ms
# Speed: 1.3ms preprocess, 200.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 88 cars, 1 truck, 199.1ms
# Speed: 1.8ms preprocess, 199.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 88 cars, 1 truck, 199.2ms
# Speed: 1.3ms preprocess, 199.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 87 cars, 2 trucks, 200.3ms
# Speed: 1.1ms preprocess, 200.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 203.2ms
# Speed: 2.6ms preprocess, 203.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 86 cars, 2 trucks, 202.0ms
# Speed: 1.1ms preprocess, 202.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 86 cars, 2 trucks, 200.6ms
# Speed: 1.1ms preprocess, 200.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 2 trucks, 195.7ms
# Speed: 1.1ms preprocess, 195.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 2 trucks, 1 van, 194.4ms
# Speed: 1.1ms preprocess, 194.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 2 trucks, 196.7ms
# Speed: 1.1ms preprocess, 196.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 2 trucks, 1 van, 195.9ms
# Speed: 1.1ms preprocess, 195.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 1 truck, 1 van, 201.1ms
# Speed: 1.1ms preprocess, 201.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 2 trucks, 2 vans, 199.7ms
# Speed: 1.1ms preprocess, 199.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 202.5ms
# Speed: 1.3ms preprocess, 202.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 2 trucks, 2 vans, 201.8ms
# Speed: 1.1ms preprocess, 201.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 2 trucks, 2 vans, 198.9ms
# Speed: 1.6ms preprocess, 198.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 2 trucks, 2 vans, 200.3ms
# Speed: 1.5ms preprocess, 200.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 196.8ms
# Speed: 1.6ms preprocess, 196.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 199.1ms
# Speed: 1.2ms preprocess, 199.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 2 trucks, 2 vans, 199.8ms
# Speed: 1.1ms preprocess, 199.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 2 trucks, 2 vans, 193.0ms
# Speed: 1.1ms preprocess, 193.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 195.7ms
# Speed: 1.1ms preprocess, 195.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 193.4ms
# Speed: 1.1ms preprocess, 193.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 214.7ms
# Speed: 1.1ms preprocess, 214.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 199.3ms
# Speed: 1.3ms preprocess, 199.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 209.3ms
# Speed: 1.5ms preprocess, 209.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 212.0ms
# Speed: 1.5ms preprocess, 212.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 201.3ms
# Speed: 1.1ms preprocess, 201.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 86 cars, 1 truck, 1 van, 199.3ms
# Speed: 1.1ms preprocess, 199.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 201.9ms
# Speed: 1.4ms preprocess, 201.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 199.4ms
# Speed: 1.1ms preprocess, 199.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 213.9ms
# Speed: 1.3ms preprocess, 213.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 195.2ms
# Speed: 1.1ms preprocess, 195.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 1 truck, 2 vans, 196.5ms
# Speed: 1.4ms preprocess, 196.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 1 truck, 2 vans, 194.4ms
# Speed: 1.1ms preprocess, 194.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 2 vans, 195.8ms
# Speed: 1.5ms preprocess, 195.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 2 vans, 193.1ms
# Speed: 1.1ms preprocess, 193.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 199.1ms
# Speed: 1.1ms preprocess, 199.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 84 cars, 1 truck, 2 vans, 198.2ms
# Speed: 1.2ms preprocess, 198.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 1 truck, 1 van, 197.7ms
# Speed: 1.1ms preprocess, 197.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 84 cars, 1 truck, 2 vans, 200.5ms
# Speed: 1.1ms preprocess, 200.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 84 cars, 1 truck, 2 vans, 197.8ms
# Speed: 1.1ms preprocess, 197.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 199.3ms
# Speed: 1.6ms preprocess, 199.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 203.3ms
# Speed: 1.2ms preprocess, 203.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 199.1ms
# Speed: 1.2ms preprocess, 199.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 195.4ms
# Speed: 1.1ms preprocess, 195.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 82 cars, 1 truck, 2 vans, 197.1ms
# Speed: 1.1ms preprocess, 197.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 82 cars, 1 truck, 2 vans, 197.4ms
# Speed: 1.1ms preprocess, 197.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 82 cars, 1 truck, 2 vans, 195.1ms
# Speed: 1.1ms preprocess, 195.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 82 cars, 1 truck, 2 vans, 196.2ms
# Speed: 1.1ms preprocess, 196.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 193.9ms
# Speed: 1.1ms preprocess, 193.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 194.1ms
# Speed: 1.1ms preprocess, 194.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 1 van, 205.8ms
# Speed: 1.2ms preprocess, 205.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 1 van, 203.2ms
# Speed: 1.6ms preprocess, 203.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 1 van, 209.9ms
# Speed: 1.5ms preprocess, 209.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 1 van, 203.3ms
# Speed: 1.5ms preprocess, 203.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 194.9ms
# Speed: 1.2ms preprocess, 194.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 202.2ms
# Speed: 1.2ms preprocess, 202.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 201.8ms
# Speed: 1.3ms preprocess, 201.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 198.0ms
# Speed: 1.1ms preprocess, 198.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 196.3ms
# Speed: 1.1ms preprocess, 196.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 2 vans, 199.0ms
# Speed: 1.5ms preprocess, 199.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 2 vans, 219.7ms
# Speed: 1.1ms preprocess, 219.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 2 vans, 196.0ms
# Speed: 1.2ms preprocess, 196.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 2 vans, 198.2ms
# Speed: 1.1ms preprocess, 198.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 2 vans, 199.4ms
# Speed: 1.1ms preprocess, 199.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 2 vans, 199.3ms
# Speed: 1.2ms preprocess, 199.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 205.7ms
# Speed: 1.2ms preprocess, 205.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 200.6ms
# Speed: 1.3ms preprocess, 200.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 211.9ms
# Speed: 1.2ms preprocess, 211.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 200.6ms
# Speed: 1.6ms preprocess, 200.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 200.0ms
# Speed: 1.3ms preprocess, 200.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 196.0ms
# Speed: 1.1ms preprocess, 196.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 198.8ms
# Speed: 1.1ms preprocess, 198.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 196.3ms
# Speed: 1.1ms preprocess, 196.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 197.8ms
# Speed: 1.1ms preprocess, 197.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 195.2ms
# Speed: 1.1ms preprocess, 195.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 3 vans, 198.5ms
# Speed: 1.2ms preprocess, 198.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 3 vans, 196.7ms
# Speed: 1.1ms preprocess, 196.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 1 truck, 2 vans, 200.2ms
# Speed: 1.2ms preprocess, 200.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 1 truck, 2 vans, 198.8ms
# Speed: 1.1ms preprocess, 198.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 1 truck, 2 vans, 199.9ms
# Speed: 1.5ms preprocess, 199.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 2 trucks, 2 vans, 199.3ms
# Speed: 1.2ms preprocess, 199.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 2 trucks, 2 vans, 198.9ms
# Speed: 1.1ms preprocess, 198.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 2 trucks, 2 vans, 202.0ms
# Speed: 1.1ms preprocess, 202.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 201.0ms
# Speed: 1.4ms preprocess, 201.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 195.8ms
# Speed: 1.5ms preprocess, 195.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 195.3ms
# Speed: 1.1ms preprocess, 195.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 196.4ms
# Speed: 1.1ms preprocess, 196.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 198.8ms
# Speed: 1.1ms preprocess, 198.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 200.8ms
# Speed: 1.1ms preprocess, 200.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Video frame is empty or video processing has been successfully completed.

# %%
#left exit 
region_points = [(400,400),(400, 800),(600,800), (600,400)] #drowing a rectangle based on x1 = (400,400) y1 = (400,800) x2= (600,800) y2 = (600,400)


# Init Object Counter
counter = solutions.ObjectCounter(
    view_img=True,
    reg_pts=region_points,
    names=model.names,
    draw_tracks=True,
    line_thickness=2,
)

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    tracks = model.track(im0, persist=True, show=False)

    im0 = counter.start_counting(im0, tracks)
    video_writer.write(im0)

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# Polygon Counter Initiated.
#
# 0: 384x640 4 buss, 85 cars, 1 truck, 2 vans, 205.2ms
# Speed: 1.5ms preprocess, 205.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 2 trucks, 2 vans, 206.8ms
# Speed: 1.1ms preprocess, 206.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 2 trucks, 2 vans, 204.0ms
# Speed: 1.2ms preprocess, 204.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 1 truck, 2 vans, 189.5ms
# Speed: 1.0ms preprocess, 189.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 233.1ms
# Speed: 1.0ms preprocess, 233.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 198.5ms
# Speed: 1.3ms preprocess, 198.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 196.7ms
# Speed: 1.2ms preprocess, 196.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 194.4ms
# Speed: 1.1ms preprocess, 194.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 208.9ms
# Speed: 1.3ms preprocess, 208.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 18
#      16     print("Video frame is empty or video processing has been successfully completed.")
#      17     break
# ---> 18 tracks = model.track(im0, persist=True, show=False)
#      20 im0 = counter.start_counting(im0, tracks)
#      21 video_writer.write(im0)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/engine/model.py:614, in Model.track(self, source, stream, persist, **kwargs)
#     612 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     613 kwargs["mode"] = "track"
# --> 614 return self.predict(source=source, stream=stream, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/engine/model.py:567, in Model.predict(self, source, stream, predictor, **kwargs)
#     565 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     566     self.predictor.set_prompts(prompts)
# --> 567 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/engine/predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/engine/predictor.py:254, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     252 # Inference
#     253 with profilers[1]:
# --> 254     preds = self.inference(im, *args, **kwargs)
#     255     if self.args.embed:
#     256         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/engine/predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/nn/autobackend.py:456, in AutoBackend.forward(self, im, augment, visualize, embed)
#     454 # PyTorch
#     455 if self.pt or self.nn_module:
# --> 456     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     458 # TorchScript
#     459 elif self.jit:
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/nn/tasks.py:106, in BaseModel.forward(self, x, *args, **kwargs)
#     104 if isinstance(x, dict):  # for cases of training and validating while training.
#     105     return self.loss(x, *args, **kwargs)
# --> 106 return self.predict(x, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/nn/tasks.py:124, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     122 if augment:
#     123     return self._predict_augment(x)
# --> 124 return self._predict_once(x, profile, visualize, embed)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/nn/tasks.py:145, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     143 if profile:
#     144     self._profile_one_layer(m, x, dt)
# --> 145 x = m(x)  # run
#     146 y.append(x if m.i in self.save else None)  # save output
#     147 if visualize:
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/nn/modules/block.py:235, in C2f.forward(self, x)
#     233 """Forward pass through C2f layer."""
#     234 y = list(self.cv1(x).chunk(2, 1))
# --> 235 y.extend(m(y[-1]) for m in self.m)
#     236 return self.cv2(torch.cat(y, 1))
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/nn/modules/block.py:235, in <genexpr>(.0)
#     233 """Forward pass through C2f layer."""
#     234 y = list(self.cv1(x).chunk(2, 1))
# --> 235 y.extend(m(y[-1]) for m in self.m)
#     236 return self.cv2(torch.cat(y, 1))
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/nn/modules/block.py:343, in Bottleneck.forward(self, x)
#     341 def forward(self, x):
#     342     """Applies the YOLO FPN to input data."""
# --> 343     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/nn/modules/conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/activation.py:405, in SiLU.forward(self, input)
#     404 def forward(self, input: Tensor) -> Tensor:
# --> 405     return F.silu(input, inplace=self.inplace)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/functional.py:2104, in silu(input, inplace)
#    2102     return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2103 if inplace:
# -> 2104     return torch._C._nn.silu_(input)
#    2105 return torch._C._nn.silu(input)
#
# KeyboardInterrupt:

# %%
#upper exit points
region_points = [(1000,150),(1200,150), (1200,300),(1000, 300)] #drowing a rectangle based on x1 = (400,400) y1 = (400,800) x2= (600,800) y2 = (600,400)


# Init Object Counter
counter = solutions.ObjectCounter(
    view_img=True,
    reg_pts=region_points,
    names=model.names,
    draw_tracks=True,
    line_thickness=2,
)

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    tracks = model.track(im0, persist=True, show=False)

    im0 = counter.start_counting(im0, tracks)
    video_writer.write(im0)

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# Polygon Counter Initiated.
#
# 0: 384x640 4 buss, 89 cars, 1 truck, 4 vans, 308.9ms
# Speed: 3.6ms preprocess, 308.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 89 cars, 1 truck, 4 vans, 200.5ms
# Speed: 1.3ms preprocess, 200.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 89 cars, 1 truck, 4 vans, 212.9ms
# Speed: 1.1ms preprocess, 212.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 209.6ms
# Speed: 1.4ms preprocess, 209.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 191.5ms
# Speed: 1.1ms preprocess, 191.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 191.4ms
# Speed: 1.1ms preprocess, 191.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 196.0ms
# Speed: 1.1ms preprocess, 196.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 193.8ms
# Speed: 1.3ms preprocess, 193.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 205.9ms
# Speed: 1.5ms preprocess, 205.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 213.5ms
# Speed: 1.5ms preprocess, 213.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 91 cars, 1 truck, 3 vans, 202.4ms
# Speed: 1.4ms preprocess, 202.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 198.6ms
# Speed: 1.2ms preprocess, 198.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 221.1ms
# Speed: 1.5ms preprocess, 221.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 209.1ms
# Speed: 1.3ms preprocess, 209.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 203.8ms
# Speed: 1.4ms preprocess, 203.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 209.7ms
# Speed: 1.6ms preprocess, 209.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 234.7ms
# Speed: 1.3ms preprocess, 234.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 227.6ms
# Speed: 1.2ms preprocess, 227.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 213.1ms
# Speed: 1.1ms preprocess, 213.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 211.0ms
# Speed: 1.1ms preprocess, 211.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 205.3ms
# Speed: 1.2ms preprocess, 205.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 202.9ms
# Speed: 1.3ms preprocess, 202.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 199.8ms
# Speed: 1.2ms preprocess, 199.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 231.2ms
# Speed: 1.2ms preprocess, 231.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 200.2ms
# Speed: 1.2ms preprocess, 200.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 200.8ms
# Speed: 1.4ms preprocess, 200.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 197.1ms
# Speed: 1.1ms preprocess, 197.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 92 cars, 1 truck, 2 vans, 201.7ms
# Speed: 1.3ms preprocess, 201.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 18
#      16     print("Video frame is empty or video processing has been successfully completed.")
#      17     break
# ---> 18 tracks = model.track(im0, persist=True, show=False)
#      20 im0 = counter.start_counting(im0, tracks)
#      21 video_writer.write(im0)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/engine/model.py:614, in Model.track(self, source, stream, persist, **kwargs)
#     612 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     613 kwargs["mode"] = "track"
# --> 614 return self.predict(source=source, stream=stream, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/engine/model.py:567, in Model.predict(self, source, stream, predictor, **kwargs)
#     565 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     566     self.predictor.set_prompts(prompts)
# --> 567 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/engine/predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/engine/predictor.py:254, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     252 # Inference
#     253 with profilers[1]:
# --> 254     preds = self.inference(im, *args, **kwargs)
#     255     if self.args.embed:
#     256         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/engine/predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/nn/autobackend.py:456, in AutoBackend.forward(self, im, augment, visualize, embed)
#     454 # PyTorch
#     455 if self.pt or self.nn_module:
# --> 456     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     458 # TorchScript
#     459 elif self.jit:
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/nn/tasks.py:106, in BaseModel.forward(self, x, *args, **kwargs)
#     104 if isinstance(x, dict):  # for cases of training and validating while training.
#     105     return self.loss(x, *args, **kwargs)
# --> 106 return self.predict(x, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/nn/tasks.py:124, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     122 if augment:
#     123     return self._predict_augment(x)
# --> 124 return self._predict_once(x, profile, visualize, embed)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/nn/tasks.py:145, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     143 if profile:
#     144     self._profile_one_layer(m, x, dt)
# --> 145 x = m(x)  # run
#     146 y.append(x if m.i in self.save else None)  # save output
#     147 if visualize:
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/nn/modules/conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/conv.py:458, in Conv2d.forward(self, input)
#     457 def forward(self, input: Tensor) -> Tensor:
# --> 458     return self._conv_forward(input, self.weight, self.bias)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/conv.py:454, in Conv2d._conv_forward(self, input, weight, bias)
#     450 if self.padding_mode != 'zeros':
#     451     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     452                     weight, bias, self.stride,
#     453                     _pair(0), self.dilation, self.groups)
# --> 454 return F.conv2d(input, weight, bias, self.stride,
#     455                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Process Video Frames and Identify Vehicles Left the Road Form Each Street

# %% [markdown]
# For each frame in the video, use the YOLO model to detect and track vehicles. You will need to write a loop that processes each frame and applies the YOLO model.
#
# In each frame, after detecting the vehicles, determine whether they exited the road via the top, bottom, left, or right street. You can use the positions of the bounding boxes provided by YOLO to do this.
#
# - The video should display bounding boxes around the detected objects.
# - The video should display your name on the top.
# - It should display the calculated center of each vehicle.
# - The video should display the confidence score, alongside the object ID and class ID of each detected and tracked object.
# - The video should display the rectangles representing the regions where you count the vehicles that have crossed and exited.
# - The video should display the number of vehicles that exited via the top street.
# - The video should display the number of vehicles that exited via the bottom street.
# - The video should display the number of vehicles that exited via the left street.
# - The video should display the number of vehicles that exited via the right street.

# %%
# i imported ultralytics/examples/YOLOv8-Region-Counter/yolov8_region_counter.py to my project and used the command python yolov8_region_counter.py --source "/Users/abd/Downloads/week 6 exam/ultralytics/examples/YOLOv8-Region-Counter/YOLO_Video.mp4" --save-img --view-img
# in terminal the r

# Ultralytics YOLO 🚀, AGPL-3.0 license

import argparse
from collections import defaultdict
from pathlib import Path

import cv2
import numpy as np
from shapely.geometry import Polygon
from shapely.geometry.point import Point

from ultralytics import YOLO
from ultralytics.utils.files import increment_path
from ultralytics.utils.plotting import Annotator, colors

track_history = defaultdict(list)

current_region = None
counting_regions = [
    {
        "name": "YOLOv8 Rectangle Region",
        "polygon": Polygon([(200, 250), (440, 250), (440, 550), (200, 550)]),  # Polygon points
        "counts": 0,
        "dragging": False,
        "region_color": (37, 255, 225),  # BGR Value
        "text_color": (0, 0, 0),  # Region Text Color
    },
    {
        "name": "YOLOv8 Rectangle1 Region",
        "polygon": Polygon([(200, 250), (440, 250), (440, 550), (200, 550)]),  # Polygon points
        "counts": 0,
        "dragging": False,
        "region_color": (37, 255, 225),  # BGR Value
        "text_color": (0, 0, 0),  # Region Text Color
    },
    {
        "name": "YOLOv8 Rectangle2 Region",
        "polygon": Polygon([(200, 250), (440, 250), (440, 550), (200, 550)]),  # Polygon points
        "counts": 0,
        "dragging": False,
        "region_color": (37, 255, 225),  # BGR Value
        "text_color": (0, 0, 0),  # Region Text Color
    },
    {
        "name": "YOLOv8 Rectangle3 Region",
        "polygon": Polygon([(200, 250), (440, 250), (440, 550), (200, 550)]),  # Polygon points
        "counts": 0,
        "dragging": False,
        "region_color": (37, 255, 225),  # BGR Value
        "text_color": (0, 0, 0),  # Region Text Color
    },
]


def mouse_callback(event, x, y, flags, param):
    """
    Handles mouse events for region manipulation.

    Args:
        event (int): The mouse event type (e.g., cv2.EVENT_LBUTTONDOWN).
        x (int): The x-coordinate of the mouse pointer.
        y (int): The y-coordinate of the mouse pointer.
        flags (int): Additional flags passed by OpenCV.
        param: Additional parameters passed to the callback (not used in this function).

    Global Variables:
        current_region (dict): A dictionary representing the current selected region.

    Mouse Events:
        - LBUTTONDOWN: Initiates dragging for the region containing the clicked point.
        - MOUSEMOVE: Moves the selected region if dragging is active.
        - LBUTTONUP: Ends dragging for the selected region.

    Notes:
        - This function is intended to be used as a callback for OpenCV mouse events.
        - Requires the existence of the 'counting_regions' list and the 'Polygon' class.

    Example:
        >>> cv2.setMouseCallback(window_name, mouse_callback)
    """
    global current_region

    # Mouse left button down event
    if event == cv2.EVENT_LBUTTONDOWN:
        for region in counting_regions:
            if region["polygon"].contains(Point((x, y))):
                current_region = region
                current_region["dragging"] = True
                current_region["offset_x"] = x
                current_region["offset_y"] = y

    # Mouse move event
    elif event == cv2.EVENT_MOUSEMOVE:
        if current_region is not None and current_region["dragging"]:
            dx = x - current_region["offset_x"]
            dy = y - current_region["offset_y"]
            current_region["polygon"] = Polygon(
                [(p[0] + dx, p[1] + dy) for p in current_region["polygon"].exterior.coords]
            )
            current_region["offset_x"] = x
            current_region["offset_y"] = y

    # Mouse left button up event
    elif event == cv2.EVENT_LBUTTONUP:
        if current_region is not None and current_region["dragging"]:
            current_region["dragging"] = False


def run(
    weights="/Users/abd/Downloads/week 6 exam/ultralytics/examples/YOLOv8-Region-Counter/YOLO_Model.pt",
    source='/Users/abd/Downloads/week 6 exam/YOLO_Video.mp4',
    device="cpu",
    view_img=False,
    save_img=False,
    exist_ok=False,
    classes=None,
    line_thickness=2,
    track_thickness=2,
    region_thickness=2,
):
    """
    Run Region counting on a video using YOLOv8 and ByteTrack.

    Supports movable region for real time counting inside specific area.
    Supports multiple regions counting.
    Regions can be Polygons or rectangle in shape

    Args:
        weights (str): Model weights path.
        source (str): Video file path.
        device (str): processing device cpu, 0, 1
        view_img (bool): Show results.
        save_img (bool): Save results.
        exist_ok (bool): Overwrite existing files.
        classes (list): classes to detect and track
        line_thickness (int): Bounding box thickness.
        track_thickness (int): Tracking line thickness
        region_thickness (int): Region thickness.
    """
    vid_frame_count = 0

    # Check source path
    if not Path(source).exists():
        raise FileNotFoundError(f"Source path '{source}' does not exist.")

    # Setup Model
    model = YOLO(f"{weights}")
    model.to("cuda") if device == "0" else model.to("cpu")

    # Extract classes names
    names = model.model.names

    # Video setup
    videocapture = cv2.VideoCapture(source)
    frame_width, frame_height = int(videocapture.get(3)), int(videocapture.get(4))
    fps, fourcc = int(videocapture.get(5)), cv2.VideoWriter_fourcc(*"mp4v")

    # Output setup
    save_dir = increment_path(Path("ultralytics_rc_output") / "exp", exist_ok)
    save_dir.mkdir(parents=True, exist_ok=True)
    video_writer = cv2.VideoWriter(str(save_dir / f"{Path(source).stem}.mp4"), fourcc, fps, (frame_width, frame_height))

    # Iterate over video frames
    while videocapture.isOpened():
        success, frame = videocapture.read()
        if not success:
            break
        vid_frame_count += 1

        # Extract the results
        results = model.track(frame, persist=True, classes=classes)

        if results[0].boxes.id is not None:
            boxes = results[0].boxes.xyxy.cpu()
            track_ids = results[0].boxes.id.int().cpu().tolist()
            clss = results[0].boxes.cls.cpu().tolist()

            annotator = Annotator(frame, line_width=line_thickness, example=str(names))

            for box, track_id, cls in zip(boxes, track_ids, clss):
                annotator.box_label(box, str(names[cls]), color=colors(cls, True))
                bbox_center = (box[0] + box[2]) / 2, (box[1] + box[3]) / 2  # Bbox center

                track = track_history[track_id]  # Tracking Lines plot
                track.append((float(bbox_center[0]), float(bbox_center[1])))
                if len(track) > 30:
                    track.pop(0)
                points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
                cv2.polylines(frame, [points], isClosed=False, color=colors(cls, True), thickness=track_thickness)

                # Check if detection inside region
                for region in counting_regions:
                    if region["polygon"].contains(Point((bbox_center[0], bbox_center[1]))):
                        region["counts"] += 1

        # Draw regions (Polygons/Rectangles)
        for region in counting_regions:
            region_label = str(region["counts"])
            region_color = region["region_color"]
            region_text_color = region["text_color"]

            polygon_coords = np.array(region["polygon"].exterior.coords, dtype=np.int32)
            centroid_x, centroid_y = int(region["polygon"].centroid.x), int(region["polygon"].centroid.y)

            text_size, _ = cv2.getTextSize(
                region_label, cv2.FONT_HERSHEY_SIMPLEX, fontScale=0.7, thickness=line_thickness
            )
            text_x = centroid_x - text_size[0] // 2
            text_y = centroid_y + text_size[1] // 2
            cv2.rectangle(
                frame,
                (text_x - 5, text_y - text_size[1] - 5),
                (text_x + text_size[0] + 5, text_y + 5),
                region_color,
                -1,
            )
            cv2.putText(
                frame, region_label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, region_text_color, line_thickness
            )
            cv2.polylines(frame, [polygon_coords], isClosed=True, color=region_color, thickness=region_thickness)

        if view_img:
            if vid_frame_count == 1:
                cv2.namedWindow("Ultralytics YOLOv8 Region Counter Movable")
                cv2.setMouseCallback("Ultralytics YOLOv8 Region Counter Movable", mouse_callback)
            cv2.imshow("Ultralytics YOLOv8 Region Counter Movable", frame)

        if save_img:
            video_writer.write(frame)

        for region in counting_regions:  # Reinitialize count for each region
            region["counts"] = 0

        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    del vid_frame_count
    video_writer.release()
    videocapture.release()
    cv2.destroyAllWindows()


# def parse_opt():
#     """Parse command line arguments."""
#     parser = argparse.ArgumentParser()
#     parser.add_argument("--weights", type=str, default="yolov8n.pt", help="initial weights path")
#     parser.add_argument("--device", default="", help="cuda device, i.e. 0 or 0,1,2,3 or cpu")
#     parser.add_argument("--source", type=str, required=True, help="video file path")
#     parser.add_argument("--view-img", action="store_true", help="show results")
#     parser.add_argument("--save-img", action="store_true", help="save results")
#     parser.add_argument("--exist-ok", action="store_true", help="existing project/name ok, do not increment")
#     parser.add_argument("--classes", nargs="+", type=int, help="filter by class: --classes 0, or --classes 0 2 3")
#     parser.add_argument("--line-thickness", type=int, default=2, help="bounding box thickness")
#     parser.add_argument("--track-thickness", type=int, default=2, help="Tracking line thickness")
#     parser.add_argument("--region-thickness", type=int, default=4, help="Region thickness")

#     return parser.parse_args()


# def main(opt):
#     """Main function."""
#     run(**vars(opt))


# if __name__ == "__main__":
#     opt = parse_opt()
#     main(opt)

# %% [markdown]
# ## Save and Submit Your Work

# %% [markdown]
# Submit both the notebook and the output video

# %%
import cv2

from ultralytics import YOLO, solutions

model = YOLO("/Users/abd/Downloads/week 6 exam/YOLO_Model.pt")
cap = cv2.VideoCapture("/Users/abd/Downloads/week 6 exam/YOLO_Video.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

region_points = [(20, 400), (1080, 404), (1080, 360), (20, 360)]

# Video writer
video_writer = cv2.VideoWriter("object_counting_output.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Init Object Counter
counter = solutions.ObjectCounter(
    view_img=True,
    reg_pts=region_points,
    names=model.names,
    draw_tracks=True,
    line_thickness=2,
)

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    tracks = model.track(im0, persist=True, show=False)

    im0 = counter.start_counting(im0, tracks)
    video_writer.write(im0)

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# Polygon Counter Initiated.
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Collecting lapx>=0.5.2
#   Downloading lapx-0.5.10.post1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
# Downloading lapx-0.5.10.post1-cp311-cp311-macosx_11_0_arm64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 4.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: lapx
# Successfully installed lapx-0.5.10.post1
#
# requirements: AutoUpdate success ✅ 3.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# 0: 384x640 2 buss, 81 cars, 2 trucks, 1 van, 238.8ms
# Speed: 2.7ms preprocess, 238.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 81 cars, 2 trucks, 1 van, 235.8ms
# Speed: 2.2ms preprocess, 235.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 81 cars, 2 trucks, 2 vans, 221.4ms
# Speed: 1.3ms preprocess, 221.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 81 cars, 2 trucks, 2 vans, 214.1ms
# Speed: 1.3ms preprocess, 214.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 81 cars, 2 trucks, 2 vans, 218.6ms
# Speed: 1.4ms preprocess, 218.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 82 cars, 2 trucks, 2 vans, 217.8ms
# Speed: 1.7ms preprocess, 217.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 82 cars, 2 trucks, 2 vans, 213.1ms
# Speed: 1.6ms preprocess, 213.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 83 cars, 2 trucks, 2 vans, 206.4ms
# Speed: 1.5ms preprocess, 206.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 83 cars, 2 trucks, 2 vans, 204.9ms
# Speed: 1.1ms preprocess, 204.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 84 cars, 2 trucks, 2 vans, 200.6ms
# Speed: 1.2ms preprocess, 200.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 84 cars, 2 trucks, 2 vans, 200.3ms
# Speed: 1.1ms preprocess, 200.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 84 cars, 2 trucks, 2 vans, 203.2ms
# Speed: 1.3ms preprocess, 203.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 83 cars, 2 trucks, 3 vans, 210.1ms
# Speed: 1.2ms preprocess, 210.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 83 cars, 2 trucks, 3 vans, 209.7ms
# Speed: 1.9ms preprocess, 209.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 83 cars, 2 trucks, 3 vans, 216.7ms
# Speed: 1.3ms preprocess, 216.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 83 cars, 2 trucks, 3 vans, 213.6ms
# Speed: 1.9ms preprocess, 213.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 84 cars, 2 trucks, 4 vans, 207.4ms
# Speed: 1.9ms preprocess, 207.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 84 cars, 2 trucks, 4 vans, 208.3ms
# Speed: 2.0ms preprocess, 208.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 85 cars, 1 truck, 3 vans, 210.0ms
# Speed: 1.3ms preprocess, 210.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 86 cars, 1 truck, 2 vans, 207.8ms
# Speed: 1.2ms preprocess, 207.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 86 cars, 1 truck, 2 vans, 225.1ms
# Speed: 1.2ms preprocess, 225.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 86 cars, 1 truck, 2 vans, 202.7ms
# Speed: 1.1ms preprocess, 202.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 86 cars, 1 truck, 2 vans, 199.2ms
# Speed: 1.2ms preprocess, 199.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 86 cars, 1 truck, 2 vans, 207.1ms
# Speed: 2.3ms preprocess, 207.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 85 cars, 2 trucks, 2 vans, 203.6ms
# Speed: 1.1ms preprocess, 203.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 85 cars, 2 trucks, 2 vans, 208.6ms
# Speed: 1.1ms preprocess, 208.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 1 truck, 2 vans, 226.1ms
# Speed: 1.1ms preprocess, 226.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 85 cars, 1 truck, 3 vans, 233.6ms
# Speed: 1.5ms preprocess, 233.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 83 cars, 1 truck, 4 vans, 239.0ms
# Speed: 7.0ms preprocess, 239.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 82 cars, 1 truck, 4 vans, 217.1ms
# Speed: 2.7ms preprocess, 217.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 81 cars, 1 truck, 5 vans, 212.6ms
# Speed: 1.3ms preprocess, 212.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 81 cars, 1 truck, 5 vans, 219.1ms
# Speed: 1.3ms preprocess, 219.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 82 cars, 1 truck, 5 vans, 250.2ms
# Speed: 1.4ms preprocess, 250.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 82 cars, 1 truck, 5 vans, 204.0ms
# Speed: 1.3ms preprocess, 204.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 82 cars, 1 truck, 5 vans, 216.3ms
# Speed: 1.1ms preprocess, 216.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 81 cars, 1 truck, 5 vans, 211.8ms
# Speed: 1.3ms preprocess, 211.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 81 cars, 2 trucks, 5 vans, 205.2ms
# Speed: 1.2ms preprocess, 205.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 82 cars, 2 trucks, 4 vans, 236.9ms
# Speed: 1.2ms preprocess, 236.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 82 cars, 2 trucks, 4 vans, 221.5ms
# Speed: 2.4ms preprocess, 221.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 82 cars, 1 truck, 4 vans, 222.2ms
# Speed: 1.4ms preprocess, 222.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 83 cars, 2 trucks, 3 vans, 237.1ms
# Speed: 1.7ms preprocess, 237.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 82 cars, 2 trucks, 4 vans, 207.4ms
# Speed: 1.3ms preprocess, 207.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 3 vans, 207.4ms
# Speed: 1.3ms preprocess, 207.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 3 vans, 210.8ms
# Speed: 1.9ms preprocess, 210.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 84 cars, 1 truck, 3 vans, 293.0ms
# Speed: 1.1ms preprocess, 293.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 83 cars, 1 truck, 3 vans, 201.2ms
# Speed: 1.5ms preprocess, 201.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 82 cars, 2 trucks, 3 vans, 208.4ms
# Speed: 1.1ms preprocess, 208.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 82 cars, 2 trucks, 3 vans, 205.6ms
# Speed: 1.1ms preprocess, 205.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 82 cars, 2 trucks, 3 vans, 229.4ms
# Speed: 1.2ms preprocess, 229.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 82 cars, 2 trucks, 3 vans, 206.5ms
# Speed: 1.4ms preprocess, 206.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 81 cars, 1 truck, 4 vans, 229.0ms
# Speed: 1.3ms preprocess, 229.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 81 cars, 2 trucks, 4 vans, 220.7ms
# Speed: 1.2ms preprocess, 220.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 81 cars, 2 trucks, 4 vans, 214.6ms
# Speed: 1.9ms preprocess, 214.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 81 cars, 2 trucks, 4 vans, 211.4ms
# Speed: 1.2ms preprocess, 211.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 80 cars, 2 trucks, 4 vans, 207.2ms
# Speed: 1.3ms preprocess, 207.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 84 cars, 2 trucks, 2 vans, 210.4ms
# Speed: 1.3ms preprocess, 210.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 83 cars, 2 trucks, 3 vans, 205.9ms
# Speed: 1.2ms preprocess, 205.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 1 truck, 2 vans, 206.4ms
# Speed: 1.1ms preprocess, 206.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 84 cars, 2 trucks, 3 vans, 208.2ms
# Speed: 1.8ms preprocess, 208.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 2 trucks, 2 vans, 212.0ms
# Speed: 1.4ms preprocess, 212.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 1 truck, 3 vans, 212.1ms
# Speed: 3.4ms preprocess, 212.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 203.8ms
# Speed: 1.1ms preprocess, 203.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 84 cars, 2 trucks, 3 vans, 201.2ms
# Speed: 1.1ms preprocess, 201.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 84 cars, 2 trucks, 3 vans, 211.4ms
# Speed: 1.3ms preprocess, 211.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 1 truck, 3 vans, 213.1ms
# Speed: 1.2ms preprocess, 213.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 2 trucks, 3 vans, 215.4ms
# Speed: 1.3ms preprocess, 215.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 1 truck, 3 vans, 212.7ms
# Speed: 1.7ms preprocess, 212.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 1 truck, 3 vans, 211.5ms
# Speed: 1.3ms preprocess, 211.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 2 trucks, 3 vans, 215.2ms
# Speed: 1.3ms preprocess, 215.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 2 trucks, 3 vans, 205.2ms
# Speed: 1.3ms preprocess, 205.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 2 trucks, 3 vans, 204.4ms
# Speed: 1.2ms preprocess, 204.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 2 trucks, 3 vans, 205.1ms
# Speed: 1.1ms preprocess, 205.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 2 trucks, 3 vans, 210.4ms
# Speed: 1.1ms preprocess, 210.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 2 trucks, 3 vans, 203.4ms
# Speed: 1.5ms preprocess, 203.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 2 trucks, 3 vans, 205.7ms
# Speed: 1.2ms preprocess, 205.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 2 trucks, 3 vans, 212.0ms
# Speed: 1.4ms preprocess, 212.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 86 cars, 1 truck, 3 vans, 223.3ms
# Speed: 1.2ms preprocess, 223.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 2 trucks, 3 vans, 212.9ms
# Speed: 1.9ms preprocess, 212.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 2 vans, 214.1ms
# Speed: 1.9ms preprocess, 214.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 3 vans, 230.5ms
# Speed: 1.2ms preprocess, 230.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 3 vans, 214.3ms
# Speed: 1.2ms preprocess, 214.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 3 vans, 208.6ms
# Speed: 1.3ms preprocess, 208.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 3 vans, 206.2ms
# Speed: 1.1ms preprocess, 206.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 3 vans, 205.1ms
# Speed: 1.1ms preprocess, 205.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 3 vans, 204.0ms
# Speed: 1.4ms preprocess, 204.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 3 vans, 202.7ms
# Speed: 1.2ms preprocess, 202.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 3 vans, 209.2ms
# Speed: 1.2ms preprocess, 209.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 3 vans, 206.1ms
# Speed: 1.4ms preprocess, 206.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 3 vans, 211.2ms
# Speed: 1.7ms preprocess, 211.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 3 vans, 214.5ms
# Speed: 2.0ms preprocess, 214.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 3 vans, 211.9ms
# Speed: 1.3ms preprocess, 211.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 3 vans, 207.4ms
# Speed: 1.4ms preprocess, 207.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 3 vans, 210.2ms
# Speed: 1.9ms preprocess, 210.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 3 vans, 228.9ms
# Speed: 1.8ms preprocess, 228.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 3 vans, 221.5ms
# Speed: 1.9ms preprocess, 221.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 3 vans, 203.7ms
# Speed: 1.1ms preprocess, 203.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 3 vans, 197.6ms
# Speed: 1.1ms preprocess, 197.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 3 vans, 201.1ms
# Speed: 1.7ms preprocess, 201.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 3 vans, 210.3ms
# Speed: 1.2ms preprocess, 210.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 3 vans, 203.5ms
# Speed: 1.2ms preprocess, 203.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 3 vans, 229.1ms
# Speed: 1.8ms preprocess, 229.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 2 vans, 211.5ms
# Speed: 1.1ms preprocess, 211.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 2 vans, 211.6ms
# Speed: 1.9ms preprocess, 211.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 2 vans, 213.6ms
# Speed: 1.3ms preprocess, 213.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 3 vans, 214.7ms
# Speed: 1.2ms preprocess, 214.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 3 vans, 212.2ms
# Speed: 1.3ms preprocess, 212.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 3 vans, 220.3ms
# Speed: 1.7ms preprocess, 220.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 3 vans, 211.3ms
# Speed: 1.3ms preprocess, 211.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 3 vans, 203.6ms
# Speed: 1.1ms preprocess, 203.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 2 trucks, 3 vans, 197.9ms
# Speed: 1.1ms preprocess, 197.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 3 vans, 205.9ms
# Speed: 1.2ms preprocess, 205.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 3 vans, 201.8ms
# Speed: 1.3ms preprocess, 201.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 3 vans, 204.0ms
# Speed: 1.1ms preprocess, 204.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 3 vans, 199.0ms
# Speed: 1.1ms preprocess, 199.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 3 vans, 217.1ms
# Speed: 1.2ms preprocess, 217.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 3 vans, 213.9ms
# Speed: 1.3ms preprocess, 213.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 3 vans, 211.4ms
# Speed: 1.9ms preprocess, 211.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 3 vans, 212.2ms
# Speed: 1.3ms preprocess, 212.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 3 vans, 208.9ms
# Speed: 1.9ms preprocess, 208.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 3 vans, 212.7ms
# Speed: 1.9ms preprocess, 212.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 2 trucks, 3 vans, 215.3ms
# Speed: 1.3ms preprocess, 215.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 2 trucks, 3 vans, 204.4ms
# Speed: 1.2ms preprocess, 204.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 2 trucks, 3 vans, 208.9ms
# Speed: 3.7ms preprocess, 208.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 2 trucks, 2 vans, 204.2ms
# Speed: 1.1ms preprocess, 204.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 2 trucks, 2 vans, 211.8ms
# Speed: 1.6ms preprocess, 211.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 91 cars, 1 truck, 2 vans, 202.2ms
# Speed: 1.1ms preprocess, 202.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 89 cars, 1 truck, 3 vans, 288.8ms
# Speed: 1.1ms preprocess, 288.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 2 vans, 210.7ms
# Speed: 1.2ms preprocess, 210.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 2 vans, 214.4ms
# Speed: 1.3ms preprocess, 214.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 2 vans, 215.7ms
# Speed: 1.3ms preprocess, 215.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 2 vans, 213.2ms
# Speed: 1.3ms preprocess, 213.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 2 trucks, 2 vans, 218.1ms
# Speed: 1.3ms preprocess, 218.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 2 trucks, 2 vans, 211.7ms
# Speed: 1.9ms preprocess, 211.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 2 vans, 204.9ms
# Speed: 1.3ms preprocess, 204.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 2 vans, 198.4ms
# Speed: 1.1ms preprocess, 198.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 2 vans, 204.6ms
# Speed: 1.2ms preprocess, 204.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 2 vans, 203.6ms
# Speed: 1.2ms preprocess, 203.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 2 vans, 207.5ms
# Speed: 1.7ms preprocess, 207.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 3 vans, 203.6ms
# Speed: 1.2ms preprocess, 203.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 3 vans, 222.0ms
# Speed: 1.7ms preprocess, 222.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 3 vans, 220.5ms
# Speed: 1.2ms preprocess, 220.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 1 truck, 4 vans, 233.4ms
# Speed: 1.3ms preprocess, 233.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 1 truck, 5 vans, 214.3ms
# Speed: 1.9ms preprocess, 214.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 1 truck, 5 vans, 215.3ms
# Speed: 1.8ms preprocess, 215.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 1 truck, 5 vans, 219.2ms
# Speed: 1.9ms preprocess, 219.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 1 truck, 5 vans, 209.1ms
# Speed: 1.4ms preprocess, 209.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 1 truck, 5 vans, 199.0ms
# Speed: 1.1ms preprocess, 199.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 87 cars, 1 truck, 4 vans, 204.6ms
# Speed: 1.1ms preprocess, 204.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 86 cars, 2 trucks, 4 vans, 208.5ms
# Speed: 1.1ms preprocess, 208.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 86 cars, 2 trucks, 4 vans, 209.5ms
# Speed: 1.1ms preprocess, 209.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 buss, 87 cars, 1 truck, 4 vans, 214.2ms
# Speed: 1.1ms preprocess, 214.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 buss, 87 cars, 1 truck, 5 vans, 201.6ms
# Speed: 1.2ms preprocess, 201.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 buss, 90 cars, 1 truck, 4 vans, 207.8ms
# Speed: 1.3ms preprocess, 207.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 91 cars, 1 truck, 4 vans, 213.4ms
# Speed: 1.3ms preprocess, 213.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 89 cars, 1 truck, 4 vans, 225.2ms
# Speed: 1.1ms preprocess, 225.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 89 cars, 1 truck, 4 vans, 204.9ms
# Speed: 1.3ms preprocess, 204.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 89 cars, 1 truck, 4 vans, 221.8ms
# Speed: 1.3ms preprocess, 221.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 1 truck, 5 vans, 215.5ms
# Speed: 1.4ms preprocess, 215.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 1 truck, 5 vans, 219.7ms
# Speed: 1.2ms preprocess, 219.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 1 truck, 5 vans, 213.3ms
# Speed: 1.1ms preprocess, 213.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 3 vans, 202.1ms
# Speed: 1.2ms preprocess, 202.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 3 vans, 204.3ms
# Speed: 1.5ms preprocess, 204.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 206.3ms
# Speed: 2.3ms preprocess, 206.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 204.6ms
# Speed: 1.3ms preprocess, 204.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 207.3ms
# Speed: 1.4ms preprocess, 207.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 3 vans, 214.2ms
# Speed: 1.1ms preprocess, 214.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 3 vans, 209.9ms
# Speed: 1.3ms preprocess, 209.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 216.2ms
# Speed: 1.9ms preprocess, 216.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 213.5ms
# Speed: 1.2ms preprocess, 213.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 215.6ms
# Speed: 1.2ms preprocess, 215.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 5 vans, 213.5ms
# Speed: 1.9ms preprocess, 213.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 5 vans, 206.8ms
# Speed: 1.8ms preprocess, 206.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 5 vans, 210.7ms
# Speed: 1.1ms preprocess, 210.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 203.0ms
# Speed: 1.1ms preprocess, 203.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 5 vans, 205.8ms
# Speed: 1.1ms preprocess, 205.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 4 vans, 214.6ms
# Speed: 1.7ms preprocess, 214.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 217.2ms
# Speed: 1.1ms preprocess, 217.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 205.7ms
# Speed: 1.1ms preprocess, 205.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 3 vans, 210.9ms
# Speed: 1.1ms preprocess, 210.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 236.7ms
# Speed: 1.2ms preprocess, 236.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 310.9ms
# Speed: 1.4ms preprocess, 310.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 289.1ms
# Speed: 2.2ms preprocess, 289.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 218.6ms
# Speed: 1.8ms preprocess, 218.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 209.1ms
# Speed: 1.9ms preprocess, 209.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 208.5ms
# Speed: 1.2ms preprocess, 208.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 208.1ms
# Speed: 1.2ms preprocess, 208.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 210.3ms
# Speed: 1.1ms preprocess, 210.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 200.2ms
# Speed: 1.1ms preprocess, 200.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 204.2ms
# Speed: 1.1ms preprocess, 204.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 212.6ms
# Speed: 1.2ms preprocess, 212.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 208.9ms
# Speed: 1.1ms preprocess, 208.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 212.5ms
# Speed: 1.2ms preprocess, 212.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 213.3ms
# Speed: 1.9ms preprocess, 213.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 212.5ms
# Speed: 1.9ms preprocess, 212.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 212.9ms
# Speed: 2.0ms preprocess, 212.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 213.5ms
# Speed: 1.3ms preprocess, 213.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 214.8ms
# Speed: 1.2ms preprocess, 214.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 202.8ms
# Speed: 1.1ms preprocess, 202.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 204.5ms
# Speed: 1.1ms preprocess, 204.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 201.6ms
# Speed: 1.1ms preprocess, 201.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 203.1ms
# Speed: 1.2ms preprocess, 203.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 205.5ms
# Speed: 1.7ms preprocess, 205.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 90 cars, 1 truck, 4 vans, 203.3ms
# Speed: 1.8ms preprocess, 203.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 89 cars, 1 truck, 4 vans, 222.5ms
# Speed: 1.5ms preprocess, 222.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 4 vans, 221.3ms
# Speed: 1.3ms preprocess, 221.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 4 vans, 212.9ms
# Speed: 1.3ms preprocess, 212.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 4 vans, 220.2ms
# Speed: 1.3ms preprocess, 220.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 4 vans, 215.1ms
# Speed: 1.3ms preprocess, 215.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 4 vans, 227.5ms
# Speed: 1.3ms preprocess, 227.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 4 vans, 209.5ms
# Speed: 2.0ms preprocess, 209.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 4 vans, 203.8ms
# Speed: 1.1ms preprocess, 203.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 211.0ms
# Speed: 1.1ms preprocess, 211.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 4 vans, 204.6ms
# Speed: 1.1ms preprocess, 204.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 205.0ms
# Speed: 1.4ms preprocess, 205.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 202.1ms
# Speed: 1.1ms preprocess, 202.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 3 vans, 204.9ms
# Speed: 1.1ms preprocess, 204.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 210.1ms
# Speed: 1.2ms preprocess, 210.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 210.5ms
# Speed: 1.2ms preprocess, 210.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 240.5ms
# Speed: 1.3ms preprocess, 240.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 217.2ms
# Speed: 1.9ms preprocess, 217.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 210.9ms
# Speed: 1.3ms preprocess, 210.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 4 vans, 213.0ms
# Speed: 1.2ms preprocess, 213.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 205.7ms
# Speed: 1.5ms preprocess, 205.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 198.3ms
# Speed: 1.1ms preprocess, 198.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 217.9ms
# Speed: 2.4ms preprocess, 217.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 206.5ms
# Speed: 1.3ms preprocess, 206.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 201.4ms
# Speed: 1.5ms preprocess, 201.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 209.2ms
# Speed: 1.3ms preprocess, 209.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 209.5ms
# Speed: 1.1ms preprocess, 209.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 216.9ms
# Speed: 1.2ms preprocess, 216.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 220.9ms
# Speed: 1.3ms preprocess, 220.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 3 vans, 207.8ms
# Speed: 1.9ms preprocess, 207.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 3 vans, 208.8ms
# Speed: 1.9ms preprocess, 208.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 3 vans, 209.1ms
# Speed: 1.2ms preprocess, 209.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 4 vans, 214.9ms
# Speed: 1.4ms preprocess, 214.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 3 vans, 207.5ms
# Speed: 1.1ms preprocess, 207.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 3 vans, 206.2ms
# Speed: 1.2ms preprocess, 206.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 201.0ms
# Speed: 1.4ms preprocess, 201.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 201.6ms
# Speed: 1.1ms preprocess, 201.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 206.3ms
# Speed: 1.1ms preprocess, 206.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 202.2ms
# Speed: 1.1ms preprocess, 202.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 209.9ms
# Speed: 1.1ms preprocess, 209.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 221.9ms
# Speed: 1.3ms preprocess, 221.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 213.0ms
# Speed: 1.1ms preprocess, 213.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 210.1ms
# Speed: 1.3ms preprocess, 210.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 228.7ms
# Speed: 1.9ms preprocess, 228.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 212.6ms
# Speed: 1.3ms preprocess, 212.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 210.0ms
# Speed: 1.9ms preprocess, 210.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 209.5ms
# Speed: 1.1ms preprocess, 209.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 3 vans, 204.0ms
# Speed: 1.2ms preprocess, 204.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 2 trucks, 2 vans, 204.4ms
# Speed: 1.2ms preprocess, 204.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 205.3ms
# Speed: 1.1ms preprocess, 205.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 90 cars, 1 truck, 4 vans, 203.1ms
# Speed: 1.1ms preprocess, 203.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 208.0ms
# Speed: 1.4ms preprocess, 208.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 4 vans, 212.3ms
# Speed: 1.1ms preprocess, 212.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 212.0ms
# Speed: 1.9ms preprocess, 212.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 210.6ms
# Speed: 1.8ms preprocess, 210.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 219.6ms
# Speed: 1.2ms preprocess, 219.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 2 vans, 227.3ms
# Speed: 1.3ms preprocess, 227.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 222.8ms
# Speed: 1.3ms preprocess, 222.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 212.5ms
# Speed: 2.0ms preprocess, 212.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 3 vans, 206.3ms
# Speed: 1.1ms preprocess, 206.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 5 vans, 203.6ms
# Speed: 1.1ms preprocess, 203.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 201.0ms
# Speed: 1.1ms preprocess, 201.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 5 vans, 283.8ms
# Speed: 1.1ms preprocess, 283.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 235.3ms
# Speed: 1.2ms preprocess, 235.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 230.0ms
# Speed: 1.1ms preprocess, 230.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 2 vans, 216.7ms
# Speed: 1.9ms preprocess, 216.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 3 vans, 218.4ms
# Speed: 1.3ms preprocess, 218.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 2 vans, 212.1ms
# Speed: 1.3ms preprocess, 212.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 3 vans, 213.5ms
# Speed: 1.3ms preprocess, 213.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 3 vans, 208.5ms
# Speed: 1.3ms preprocess, 208.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 3 vans, 219.2ms
# Speed: 1.9ms preprocess, 219.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 3 vans, 202.0ms
# Speed: 1.3ms preprocess, 202.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 5 vans, 200.4ms
# Speed: 1.1ms preprocess, 200.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 208.4ms
# Speed: 1.1ms preprocess, 208.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 202.9ms
# Speed: 1.1ms preprocess, 202.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 201.3ms
# Speed: 1.2ms preprocess, 201.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 3 vans, 203.7ms
# Speed: 1.1ms preprocess, 203.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 200.2ms
# Speed: 1.1ms preprocess, 200.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 91 cars, 1 truck, 5 vans, 214.2ms
# Speed: 1.3ms preprocess, 214.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 210.3ms
# Speed: 1.2ms preprocess, 210.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 4 vans, 212.6ms
# Speed: 1.2ms preprocess, 212.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 93 cars, 1 truck, 3 vans, 209.6ms
# Speed: 1.8ms preprocess, 209.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 3 vans, 209.7ms
# Speed: 1.9ms preprocess, 209.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 212.0ms
# Speed: 1.3ms preprocess, 212.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 3 vans, 205.9ms
# Speed: 2.0ms preprocess, 205.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 214.9ms
# Speed: 1.1ms preprocess, 214.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 206.6ms
# Speed: 1.9ms preprocess, 206.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 3 vans, 203.0ms
# Speed: 1.2ms preprocess, 203.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 3 vans, 203.4ms
# Speed: 1.1ms preprocess, 203.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 3 vans, 200.4ms
# Speed: 1.6ms preprocess, 200.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 92 cars, 1 truck, 5 vans, 204.2ms
# Speed: 1.2ms preprocess, 204.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 3 vans, 214.8ms
# Speed: 1.2ms preprocess, 214.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 3 vans, 208.9ms
# Speed: 1.3ms preprocess, 208.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 210.8ms
# Speed: 1.2ms preprocess, 210.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 210.9ms
# Speed: 1.3ms preprocess, 210.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 3 vans, 218.8ms
# Speed: 2.0ms preprocess, 218.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 95 cars, 1 truck, 3 vans, 209.2ms
# Speed: 2.0ms preprocess, 209.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 206.1ms
# Speed: 1.9ms preprocess, 206.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 204.7ms
# Speed: 1.2ms preprocess, 204.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 205.3ms
# Speed: 1.2ms preprocess, 205.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 94 cars, 1 truck, 4 vans, 207.8ms
# Speed: 1.1ms preprocess, 207.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 205.9ms
# Speed: 1.1ms preprocess, 205.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 205.5ms
# Speed: 1.2ms preprocess, 205.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 203.8ms
# Speed: 1.3ms preprocess, 203.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 215.3ms
# Speed: 1.3ms preprocess, 215.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 205.4ms
# Speed: 1.2ms preprocess, 205.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 207.6ms
# Speed: 1.3ms preprocess, 207.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 93 cars, 1 truck, 4 vans, 217.4ms
# Speed: 1.3ms preprocess, 217.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 1 van, 199.0ms
# Speed: 1.2ms preprocess, 199.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 1 truck, 1 van, 205.2ms
# Speed: 1.4ms preprocess, 205.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 1 van, 211.1ms
# Speed: 1.3ms preprocess, 211.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 1 van, 230.1ms
# Speed: 2.1ms preprocess, 230.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 1 truck, 1 van, 213.0ms
# Speed: 1.1ms preprocess, 213.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 88 cars, 1 truck, 1 van, 209.8ms
# Speed: 1.8ms preprocess, 209.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 207.9ms
# Speed: 1.9ms preprocess, 207.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 89 cars, 1 truck, 213.5ms
# Speed: 1.2ms preprocess, 213.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 88 cars, 1 truck, 210.2ms
# Speed: 1.3ms preprocess, 210.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 87 cars, 1 truck, 200.5ms
# Speed: 1.4ms preprocess, 200.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 87 cars, 1 truck, 213.4ms
# Speed: 1.1ms preprocess, 213.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 88 cars, 1 truck, 202.8ms
# Speed: 1.1ms preprocess, 202.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 88 cars, 1 truck, 200.9ms
# Speed: 1.2ms preprocess, 200.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 88 cars, 1 truck, 203.0ms
# Speed: 1.1ms preprocess, 203.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 88 cars, 1 truck, 201.9ms
# Speed: 1.7ms preprocess, 201.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 87 cars, 2 trucks, 218.5ms
# Speed: 1.2ms preprocess, 218.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 87 cars, 2 trucks, 204.6ms
# Speed: 1.1ms preprocess, 204.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 86 cars, 2 trucks, 212.0ms
# Speed: 1.2ms preprocess, 212.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 86 cars, 2 trucks, 218.0ms
# Speed: 1.7ms preprocess, 218.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 2 trucks, 210.7ms
# Speed: 1.3ms preprocess, 210.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 2 trucks, 1 van, 210.9ms
# Speed: 1.8ms preprocess, 210.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 2 trucks, 211.6ms
# Speed: 1.2ms preprocess, 211.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 2 trucks, 1 van, 216.2ms
# Speed: 1.5ms preprocess, 216.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 1 truck, 1 van, 208.9ms
# Speed: 1.2ms preprocess, 208.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 2 trucks, 2 vans, 205.3ms
# Speed: 1.1ms preprocess, 205.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 201.5ms
# Speed: 1.1ms preprocess, 201.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 2 trucks, 2 vans, 203.6ms
# Speed: 1.5ms preprocess, 203.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 2 trucks, 2 vans, 202.2ms
# Speed: 1.1ms preprocess, 202.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 2 trucks, 2 vans, 211.2ms
# Speed: 1.3ms preprocess, 211.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 211.6ms
# Speed: 1.3ms preprocess, 211.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 208.7ms
# Speed: 1.2ms preprocess, 208.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 2 trucks, 2 vans, 211.2ms
# Speed: 1.8ms preprocess, 211.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 2 trucks, 2 vans, 212.4ms
# Speed: 1.3ms preprocess, 212.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 215.9ms
# Speed: 1.3ms preprocess, 215.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 210.9ms
# Speed: 1.2ms preprocess, 210.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 210.2ms
# Speed: 1.2ms preprocess, 210.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 201.5ms
# Speed: 1.1ms preprocess, 201.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 203.2ms
# Speed: 1.1ms preprocess, 203.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 200.6ms
# Speed: 1.7ms preprocess, 200.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 201.5ms
# Speed: 1.1ms preprocess, 201.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 86 cars, 1 truck, 1 van, 205.0ms
# Speed: 1.1ms preprocess, 205.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 240.6ms
# Speed: 1.3ms preprocess, 240.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 210.2ms
# Speed: 1.3ms preprocess, 210.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 212.3ms
# Speed: 1.2ms preprocess, 212.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 86 cars, 1 truck, 2 vans, 208.2ms
# Speed: 1.2ms preprocess, 208.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 1 truck, 2 vans, 212.6ms
# Speed: 1.3ms preprocess, 212.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 1 truck, 2 vans, 214.7ms
# Speed: 1.2ms preprocess, 214.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 2 vans, 203.4ms
# Speed: 1.2ms preprocess, 203.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 2 vans, 207.0ms
# Speed: 1.1ms preprocess, 207.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 204.2ms
# Speed: 1.7ms preprocess, 204.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 84 cars, 1 truck, 2 vans, 207.0ms
# Speed: 1.1ms preprocess, 207.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 85 cars, 1 truck, 1 van, 209.7ms
# Speed: 1.1ms preprocess, 209.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 84 cars, 1 truck, 2 vans, 203.9ms
# Speed: 1.2ms preprocess, 203.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 84 cars, 1 truck, 2 vans, 201.5ms
# Speed: 1.1ms preprocess, 201.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 220.8ms
# Speed: 1.2ms preprocess, 220.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 206.4ms
# Speed: 1.3ms preprocess, 206.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 210.5ms
# Speed: 1.3ms preprocess, 210.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 215.0ms
# Speed: 2.0ms preprocess, 215.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 82 cars, 1 truck, 2 vans, 218.5ms
# Speed: 1.2ms preprocess, 218.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 82 cars, 1 truck, 2 vans, 223.2ms
# Speed: 1.2ms preprocess, 223.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 82 cars, 1 truck, 2 vans, 210.6ms
# Speed: 2.2ms preprocess, 210.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 82 cars, 1 truck, 2 vans, 206.0ms
# Speed: 1.2ms preprocess, 206.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 203.4ms
# Speed: 1.1ms preprocess, 203.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 202.4ms
# Speed: 1.1ms preprocess, 202.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 1 van, 211.9ms
# Speed: 1.1ms preprocess, 211.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 1 van, 209.6ms
# Speed: 1.8ms preprocess, 209.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 1 van, 201.4ms
# Speed: 1.5ms preprocess, 201.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 1 van, 208.7ms
# Speed: 1.3ms preprocess, 208.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 211.7ms
# Speed: 1.1ms preprocess, 211.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 210.7ms
# Speed: 1.3ms preprocess, 210.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 214.3ms
# Speed: 1.3ms preprocess, 214.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 211.3ms
# Speed: 1.2ms preprocess, 211.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 216.0ms
# Speed: 1.2ms preprocess, 216.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 2 vans, 249.6ms
# Speed: 2.0ms preprocess, 249.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 2 vans, 206.5ms
# Speed: 1.2ms preprocess, 206.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 2 vans, 209.8ms
# Speed: 1.2ms preprocess, 209.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 2 vans, 203.2ms
# Speed: 1.1ms preprocess, 203.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 2 vans, 205.6ms
# Speed: 1.1ms preprocess, 205.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 2 vans, 220.3ms
# Speed: 1.7ms preprocess, 220.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 216.5ms
# Speed: 1.1ms preprocess, 216.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 214.7ms
# Speed: 1.9ms preprocess, 214.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 208.8ms
# Speed: 1.2ms preprocess, 208.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 213.1ms
# Speed: 1.2ms preprocess, 213.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 211.3ms
# Speed: 1.9ms preprocess, 211.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 208.9ms
# Speed: 1.2ms preprocess, 208.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 218.1ms
# Speed: 1.9ms preprocess, 218.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 234.2ms
# Speed: 1.1ms preprocess, 234.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 206.6ms
# Speed: 1.4ms preprocess, 206.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 2 vans, 204.5ms
# Speed: 1.7ms preprocess, 204.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 3 vans, 204.5ms
# Speed: 1.1ms preprocess, 204.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 83 cars, 1 truck, 3 vans, 198.5ms
# Speed: 1.1ms preprocess, 198.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 1 truck, 2 vans, 208.0ms
# Speed: 1.4ms preprocess, 208.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 1 truck, 2 vans, 207.6ms
# Speed: 1.7ms preprocess, 207.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 85 cars, 1 truck, 2 vans, 220.9ms
# Speed: 1.2ms preprocess, 220.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 2 trucks, 2 vans, 210.5ms
# Speed: 1.9ms preprocess, 210.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 2 trucks, 2 vans, 206.9ms
# Speed: 1.2ms preprocess, 206.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 2 trucks, 2 vans, 215.9ms
# Speed: 1.7ms preprocess, 215.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 227.7ms
# Speed: 3.0ms preprocess, 227.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 212.9ms
# Speed: 1.2ms preprocess, 212.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 211.5ms
# Speed: 1.2ms preprocess, 211.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 202.4ms
# Speed: 1.1ms preprocess, 202.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 214.7ms
# Speed: 1.1ms preprocess, 214.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 buss, 84 cars, 1 truck, 3 vans, 208.8ms
# Speed: 1.1ms preprocess, 208.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Video frame is empty or video processing has been successfully completed.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

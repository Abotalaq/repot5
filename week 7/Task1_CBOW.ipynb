# %% [markdown]
# # Continuous Bag of Words (CBOW) Model

# %% [markdown]
# In this exam, we will create a CBOW model using a sample Arabic traffic corpus. The corpus consists of sentences describing various traffic scenarios. The goal of the CBOW model is to predict a target word based on its surrounding context words.

# %% [markdown]
# # Importing Required Libraries

# %% [markdown]
# In this step, we import the necessary libraries to build and train the Continuous Bag of Words (CBOW) model.
#
# - **TensorFlow and Keras**: Used to build the neural network model, including the layers like `Embedding`, `Dense`, and `Lambda`.
# - **Tokenizer**: A utility from Keras for tokenizing and processing text data.
# - **NumPy**: Used for handling numerical operations, particularly for processing arrays and data manipulation.
#
# These libraries will provide the essential tools for text preprocessing and model development in the upcoming steps.
#
# Add more if needed!

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Lambda
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np

# %% [markdown]
# # Preparing the Corpus

# %% [markdown]
# In this step, we initialize the corpus that will be used for training the Continuous Bag of Words (CBOW) model. The corpus consists of Arabic sentences, each of which describes different traffic scenarios.
#
# - **Corpus**: A collection of traffic-related sentences in Arabic.
#
# This step sets up the text data that we will use in the upcoming stages of tokenization and model training.

# %%
corpus = [
    "الطريق مزدحم اليوم بسبب الحادث المروري الذي حدث صباحاً ويؤدي إلى تأخير كبير في الوصول",
    "كان الطريق مزدحما للغاية والسيارات متوقفة تقريباً نتيجة الازدحام الشديد والحركة بطيئة جداً ولا تتحسن",
    "أنا أحب الذهاب إلى السوق في الصباح الباكر لتفادي الازدحام وشراء الخضروات الطازجة دون الانتظار في الطريق",
    "السيارات بطيئة بسبب الازدحام المروري في الشارع الرئيسي والتأخير في حركة المرور خلال ساعات الذروة",
    "هناك ازدحام مروري في الشارع بسبب أعمال البناء والحفريات التي تعطل حركة السيارات وتتسبب في تأخير كبير",
    "ازدحام السيارات يزداد في المساء عندما يبدأ الجميع بالعودة إلى منازلهم من العمل وتتوقف حركة المرور بالكامل",
    "الطريق السريع يشهد ازدحاما مستمرا خلال فترة الظهيرة بسبب الشاحنات الكبيرة التي تبطئ حركة السير",
    "الحافلات والسيارات عالقة في الازدحام المروري في المنطقة التجارية مما يؤدي إلى تأخير وصول الناس إلى وجهاتهم",
    "حركة المرور مزدحمة اليوم بسبب الفعاليات التي تقام في وسط المدينة مما يزيد من صعوبة الوصول إلى هناك",
    "كان من الصعب جدا القيادة على الطريق الرئيسي اليوم بسبب الازدحام الخانق الذي استمر طوال اليوم",
    "الطريق إلى المطار مزدحم اليوم بسبب الحوادث المتكررة والتأخيرات الكبيرة في حركة المرور على الطريق السريع",
    "الشارع مزدحم بالسيارات والحافلات الكبيرة مما يجعل التنقل بطيئًا جدًا ويزيد من وقت الوصول إلى العمل",
    "ازدحام السيارات في المدينة أصبح مشكلة كبيرة خاصة خلال ساعات الذروة حيث يصعب التحرك بسرعة",
    "تفاقم الازدحام في الطرق الجانبية بسبب إغلاق الطريق الرئيسي المؤدي إلى وسط المدينة لصيانة الجسر",
    "ازدحام مروري خانق يواجه السكان يوميًا خلال تنقلهم من وإلى العمل على الطرق السريعة المؤدية إلى المدينة",
    "التأخيرات المرورية اليوم ناجمة عن سوء الأحوال الجوية والضباب الذي يعيق الرؤية ويبطئ حركة السيارات",
    "حوادث السير المتكررة على الطريق الزراعي تؤدي إلى ازدحام مروري شديد وتأخير كبير في وصول السيارات",
    "كانت حركة السير اليوم غير منتظمة بسبب تنظيم حدث رياضي كبير أدى إلى إغلاق بعض الشوارع الرئيسية",
    "الأعمال الإنشائية في الشارع الرئيسي تسببت في اختناق مروري كامل وتباطؤ في حركة السيارات خلال النهار",
    "تراكم السيارات عند تقاطع الطرق الرئيسية أدى إلى ازدحام شديد وزيادة كبيرة في مدة الانتظار للوصول إلى الجهة المطلوبة"
]

# %% [markdown]
# # Defining Vocabulary and Model Parameters

# %% [markdown]
# In this step, we define key parameters that will be used to configure the CBOW model.
#
# - **Vocabulary size**: We calculate the size of the vocabulary based on the number of unique words in the corpus. The `vocab_size` represents the total number of unique tokens (words) in the dataset plus one for padding.
#
# - **Embedding size**: The `embedding_size` defines the dimensionality of the word embeddings. In this case, we set the embedding size to 10, meaning each word will be represented as a 10-dimensional vector in the embedding layer.
#
# - **Window size**: The `window_size` defines how many words to the left and right of the target word are considered as context. Here, a window size of 2 means that two words before and two words after the target word will be used as context.
#
# These parameters will play an essential role in shaping the CBOW model architecture.

# %%
#this has been solved multiple times in labs and practic over the weekend

tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
sequences = tokenizer.texts_to_sequences(corpus)
print('result:')
print(sequences)
vocab_size = len(tokenizer.word_index) + 1
embedding_size = 10
window_size = 2
# Out:
# result:
# [[3, 19, 7, 4, 47, 20, 21, 30, 48, 49, 2, 22, 12, 1, 23], [31, 3, 50, 51, 32, 52, 53, 54, 8, 55, 56, 33, 57, 58, 59], [60, 61, 62, 2, 63, 1, 64, 65, 66, 8, 67, 68, 69, 70, 34, 1, 3], [6, 33, 4, 8, 20, 1, 13, 14, 71, 1, 5, 15, 10, 35, 36], [37, 9, 16, 1, 13, 4, 72, 73, 74, 24, 75, 5, 6, 76, 1, 22, 12], [9, 6, 77, 1, 78, 79, 80, 81, 82, 2, 83, 11, 25, 84, 5, 15, 85], [3, 38, 86, 87, 88, 10, 89, 90, 4, 91, 26, 24, 92, 5, 27], [93, 32, 94, 1, 8, 20, 1, 95, 96, 28, 97, 2, 22, 39, 98, 2, 99], [5, 15, 100, 7, 4, 101, 24, 102, 1, 40, 17, 28, 103, 11, 104, 23, 2, 37], [31, 11, 105, 106, 107, 18, 3, 14, 7, 4, 8, 108, 21, 109, 110, 7], [3, 2, 111, 19, 7, 4, 112, 41, 113, 26, 1, 5, 15, 18, 3, 38], [13, 19, 114, 115, 26, 28, 116, 117, 118, 119, 120, 11, 121, 23, 2, 25], [9, 6, 1, 17, 122, 123, 42, 124, 10, 35, 36, 125, 126, 127, 128], [129, 8, 1, 29, 130, 4, 43, 3, 14, 131, 2, 40, 17, 132, 133], [9, 16, 134, 135, 136, 137, 10, 138, 11, 139, 25, 18, 29, 140, 141, 2, 17], [142, 143, 7, 144, 145, 146, 147, 148, 149, 21, 150, 151, 152, 5, 6], [153, 27, 41, 18, 3, 154, 155, 2, 9, 16, 44, 156, 12, 1, 39, 6], [157, 5, 27, 7, 158, 159, 4, 160, 30, 161, 12, 45, 2, 43, 162, 163, 46], [164, 165, 1, 13, 14, 166, 1, 167, 16, 168, 169, 1, 5, 6, 10, 170], [171, 6, 172, 173, 29, 46, 45, 2, 9, 44, 174, 42, 1, 175, 34, 176, 2, 177, 178]]

# %% [markdown]
# # Preparing Context-Target Pairs for CBOW

# %% [markdown]
# In this step, we generate the context-target pairs from the tokenized sequences to train the CBOW model.
#
# - **Context words**: For each word in a sequence, the surrounding words (within the window size) are considered as context. The context consists of the words immediately before and after the target word.
#
# - **Target word**: The word in the middle of the context window is treated as the target word that the model will learn to predict.
#
# We iterate through each sequence, collecting the context words and corresponding target words:
# - For each word in a sequence, we gather the surrounding words based on the defined window size.
# - The middle word is the target, and the surrounding words form the context.
#
# Finally:
# - **`X`**: An array of context words.
# - **`y`**: The target words are one-hot encoded, which means they are converted into a categorical format where each word is represented as a vector of length equal to the vocabulary size.
#
# These context-target pairs will be used to train the CBOW model to predict a target word based on its context.

# %%
#this has been solved multiple times in labs and practic over the weekend


contexts = []
targets = []

for sequence in sequences:
    for i in  range(window_size, len(sequence) - window_size):
        context = sequence[i - window_size : i] + sequence[i + 1 : i + window_size + 1]
        target = sequence[i]
        contexts.append(context)
        targets.append(target)

X = np.array(contexts)
y = tf.keras.utils.to_categorical(targets, num_classes=vocab_size)

# %% [markdown]
# # Building and Training the CBOW Model

# %% [markdown]
# In this step, we build and train the Continuous Bag of Words (CBOW) model using the context-target pairs created earlier.
#
# 1. **Model architecture**:
#    - **Embedding layer**: This layer transforms the input context words into dense vector representations (embeddings) of size defined by `embedding_size`. The `input_dim` is set to the vocabulary size, and the `input_length` is twice the window size (since context consists of words from both sides of the target).
#
#    - **Lambda layer**: This layer computes the mean of the context word embeddings. It averages the embeddings of the context words to generate a single representation that will be used to predict the target word.
#
#    - **Dense layer**: This fully connected layer outputs a probability distribution over the vocabulary, using the softmax activation function. It predicts the most likely target word based on the context word embeddings.
#
# 2. **Compilation**:
#    The model is compiled using the Adam optimizer and categorical cross-entropy as the loss function, which is suitable for multi-class classification tasks. Accuracy is used as a metric to evaluate the model's performance during training.
#
# 3. **Training the model**:
#    The model is trained on the context-target pairs for 500 epochs. During each epoch, the model learns to predict the target word based on the context, refining its weights to improve accuracy.
#
# 4. **Saving the model weights**:
#    After training, the model weights are saved to a file (`cbow_model.weights.h5`) for future use. This allows us to load the trained model later without retraining.
#
# By the end of this step, the CBOW model will have learned to predict target words based on their surrounding context from the given corpus.

# %%
#this has been solved multiple times in labs and practic over the weekend

model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_size, input_length=2*window_size))
model.add(Lambda(lambda x: tf.reduce_mean(x, axis=1)))
model.add(Dense(units=vocab_size, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.fit(X, y, epochs=500, verbose=1)
model.save_weights('cbow_model.weights.h5')
# Out:
# Epoch 1/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 0.0087 - loss: 5.1869
# Epoch 2/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - accuracy: 0.0443 - loss: 5.1823
# Epoch 3/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.1086 - loss: 5.1777
# Epoch 4/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - accuracy: 0.1209 - loss: 5.1734
# Epoch 5/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.1112 - loss: 5.1684
# Epoch 6/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - accuracy: 0.1168 - loss: 5.1645
# Epoch 7/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - accuracy: 0.1303 - loss: 5.1588
# Epoch 8/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - accuracy: 0.1557 - loss: 5.1537
# Epoch 9/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.1151 - loss: 5.1518
# Epoch 10/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - accuracy: 0.1300 - loss: 5.1447
# Epoch 11/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - accuracy: 0.1545 - loss: 5.1362
# Epoch 12/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - accuracy: 0.1510 - loss: 5.1333
# Epoch 13/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - accuracy: 0.1358 - loss: 5.1264
# Epoch 14/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.1275 - loss: 5.1201
# Epoch 15/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - accuracy: 0.1527 - loss: 5.1098
# Epoch 16/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1243 - loss: 5.1057
# Epoch 17/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.1648 - loss: 5.0958
# Epoch 18/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - accuracy: 0.1716 - loss: 5.0822
# Epoch 19/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - accuracy: 0.1491 - loss: 5.0746
# Epoch 20/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - accuracy: 0.1589 - loss: 5.0666
# Epoch 21/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - accuracy: 0.1233 - loss: 5.0655
# Epoch 22/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.1391 - loss: 5.0500
# Epoch 23/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - accuracy: 0.1432 - loss: 5.0297
# Epoch 24/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.1367 - loss: 5.0161
# Epoch 25/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - accuracy: 0.1265 - loss: 5.0158
# Epoch 26/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - accuracy: 0.1682 - loss: 4.9808
# Epoch 27/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.1365 - loss: 4.9808
# Epoch 28/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - accuracy: 0.1460 - loss: 4.9642
# Epoch 29/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - accuracy: 0.1480 - loss: 4.9532
# Epoch 30/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - accuracy: 0.1194 - loss: 4.9546
# Epoch 31/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - accuracy: 0.1359 - loss: 4.9220
# Epoch 32/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - accuracy: 0.1437 - loss: 4.8857
# Epoch 33/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.1299 - loss: 4.8808
# Epoch 34/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - accuracy: 0.1318 - loss: 4.8612
# Epoch 35/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.1303 - loss: 4.8493
# Epoch 36/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.1573 - loss: 4.7908
# Epoch 37/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - accuracy: 0.1465 - loss: 4.8068
# Epoch 38/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - accuracy: 0.1309 - loss: 4.7759
# Epoch 39/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - accuracy: 0.1369 - loss: 4.7441
# Epoch 40/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - accuracy: 0.1469 - loss: 4.7373
# Epoch 41/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - accuracy: 0.1323 - loss: 4.7200
# Epoch 42/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - accuracy: 0.1055 - loss: 4.7332
# Epoch 43/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.1507 - loss: 4.6676
# Epoch 44/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - accuracy: 0.1466 - loss: 4.6223
# Epoch 45/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.1399 - loss: 4.6067
# Epoch 46/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1407 - loss: 4.5916
# Epoch 47/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - accuracy: 0.1200 - loss: 4.5989
# Epoch 48/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.1287 - loss: 4.5536
# Epoch 49/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1445 - loss: 4.5101
# Epoch 50/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - accuracy: 0.1179 - loss: 4.5073
# Epoch 51/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - accuracy: 0.1866 - loss: 4.4618
# Epoch 52/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - accuracy: 0.1429 - loss: 4.4784
# Epoch 53/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - accuracy: 0.1439 - loss: 4.4519
# Epoch 54/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.1427 - loss: 4.4309
# Epoch 55/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - accuracy: 0.1522 - loss: 4.3915
# Epoch 56/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - accuracy: 0.1518 - loss: 4.3170
# Epoch 57/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.1754 - loss: 4.2791
# Epoch 58/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - accuracy: 0.1263 - loss: 4.3737
# Epoch 59/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - accuracy: 0.1561 - loss: 4.2888
# Epoch 60/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.2007 - loss: 4.2527
# Epoch 61/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - accuracy: 0.1287 - loss: 4.3028
# Epoch 62/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - accuracy: 0.1378 - loss: 4.2612
# Epoch 63/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - accuracy: 0.1837 - loss: 4.1886
# Epoch 64/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - accuracy: 0.1625 - loss: 4.1728
# Epoch 65/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - accuracy: 0.1595 - loss: 4.1752
# Epoch 66/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - accuracy: 0.1681 - loss: 4.1774
# Epoch 67/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.1655 - loss: 4.1222
# Epoch 68/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - accuracy: 0.1275 - loss: 4.1268
# Epoch 69/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.1645 - loss: 4.0966
# Epoch 70/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - accuracy: 0.1313 - loss: 4.1191
# Epoch 71/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - accuracy: 0.1361 - loss: 4.0709
# Epoch 72/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - accuracy: 0.1358 - loss: 4.0264
# Epoch 73/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1534 - loss: 4.0061
# Epoch 74/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - accuracy: 0.1773 - loss: 3.9797
# Epoch 75/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - accuracy: 0.1824 - loss: 3.8995
# Epoch 76/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - accuracy: 0.1411 - loss: 4.0239
# Epoch 77/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.1809 - loss: 3.8439
# Epoch 78/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.1981 - loss: 3.8983
# Epoch 79/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1631 - loss: 3.9199
# Epoch 80/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.1396 - loss: 3.9022
# Epoch 81/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - accuracy: 0.1798 - loss: 3.8483
# Epoch 82/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.1547 - loss: 3.8791
# Epoch 83/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - accuracy: 0.1690 - loss: 3.8376
# Epoch 84/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - accuracy: 0.1730 - loss: 3.7688
# Epoch 85/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - accuracy: 0.1788 - loss: 3.7543
# Epoch 86/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - accuracy: 0.1829 - loss: 3.7250
# Epoch 87/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - accuracy: 0.1928 - loss: 3.7305
# Epoch 88/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - accuracy: 0.1873 - loss: 3.6939
# Epoch 89/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - accuracy: 0.1817 - loss: 3.7012
# Epoch 90/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - accuracy: 0.2034 - loss: 3.6394
# Epoch 91/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - accuracy: 0.2212 - loss: 3.6219
# Epoch 92/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - accuracy: 0.1757 - loss: 3.6077
# Epoch 93/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - accuracy: 0.2010 - loss: 3.6605
# Epoch 94/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.2363 - loss: 3.5125
# Epoch 95/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - accuracy: 0.2183 - loss: 3.5508
# Epoch 96/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - accuracy: 0.2236 - loss: 3.4869
# Epoch 97/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - accuracy: 0.2156 - loss: 3.5176
# Epoch 98/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.2179 - loss: 3.5415
# Epoch 99/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - accuracy: 0.2377 - loss: 3.4958
# Epoch 100/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.2386 - loss: 3.4041
# Epoch 101/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - accuracy: 0.2310 - loss: 3.4418
# Epoch 102/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - accuracy: 0.2460 - loss: 3.4338
# Epoch 103/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - accuracy: 0.2189 - loss: 3.4192
# Epoch 104/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - accuracy: 0.2468 - loss: 3.3571
# Epoch 105/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - accuracy: 0.2091 - loss: 3.4362
# Epoch 106/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.2115 - loss: 3.4019
# Epoch 107/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - accuracy: 0.2589 - loss: 3.3472
# Epoch 108/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - accuracy: 0.2623 - loss: 3.2699
# Epoch 109/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.2355 - loss: 3.3112
# Epoch 110/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 0.2304 - loss: 3.3517
# Epoch 111/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - accuracy: 0.2335 - loss: 3.2685
# Epoch 112/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2186 - loss: 3.2765
# Epoch 113/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - accuracy: 0.2642 - loss: 3.1993
# Epoch 114/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - accuracy: 0.2493 - loss: 3.2068
# Epoch 115/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - accuracy: 0.2732 - loss: 3.1722
# Epoch 116/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.2648 - loss: 3.1874
# Epoch 117/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.2728 - loss: 3.1849
# Epoch 118/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.2372 - loss: 3.1851
# Epoch 119/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - accuracy: 0.2287 - loss: 3.2140
# Epoch 120/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - accuracy: 0.2593 - loss: 3.1988
# Epoch 121/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - accuracy: 0.2760 - loss: 3.1189
# Epoch 122/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - accuracy: 0.2471 - loss: 3.1321
# Epoch 123/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - accuracy: 0.2656 - loss: 3.1061
# Epoch 124/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2565 - loss: 3.0936
# Epoch 125/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - accuracy: 0.2517 - loss: 3.0757
# Epoch 126/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - accuracy: 0.2775 - loss: 3.0561
# Epoch 127/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.2873 - loss: 2.9831
# Epoch 128/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - accuracy: 0.2559 - loss: 3.0563
# Epoch 129/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - accuracy: 0.2587 - loss: 3.0073
# Epoch 130/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - accuracy: 0.2355 - loss: 3.0881
# Epoch 131/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - accuracy: 0.2997 - loss: 2.9407
# Epoch 132/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - accuracy: 0.2698 - loss: 2.9734
# Epoch 133/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - accuracy: 0.2813 - loss: 2.9758
# Epoch 134/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - accuracy: 0.2685 - loss: 3.0092
# Epoch 135/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - accuracy: 0.2745 - loss: 2.9481
# Epoch 136/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.3134 - loss: 2.8805
# Epoch 137/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.3475 - loss: 2.8996
# Epoch 138/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - accuracy: 0.3431 - loss: 2.8230
# Epoch 139/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - accuracy: 0.3037 - loss: 2.8630
# Epoch 140/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - accuracy: 0.3166 - loss: 2.8597
# Epoch 141/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - accuracy: 0.3364 - loss: 2.8473
# Epoch 142/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - accuracy: 0.3263 - loss: 2.8519
# Epoch 143/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - accuracy: 0.3508 - loss: 2.7821
# Epoch 144/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - accuracy: 0.3319 - loss: 2.8072
# Epoch 145/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - accuracy: 0.3916 - loss: 2.6050
# Epoch 146/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.3173 - loss: 2.7565
# Epoch 147/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - accuracy: 0.3142 - loss: 2.7583
# Epoch 148/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.3309 - loss: 2.7388
# Epoch 149/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - accuracy: 0.3522 - loss: 2.7178
# Epoch 150/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - accuracy: 0.3603 - loss: 2.6431
# Epoch 151/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.3431 - loss: 2.6767
# Epoch 152/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - accuracy: 0.3297 - loss: 2.7297
# Epoch 153/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - accuracy: 0.3537 - loss: 2.6053
# Epoch 154/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - accuracy: 0.3577 - loss: 2.5972
# Epoch 155/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step - accuracy: 0.3515 - loss: 2.6381
# Epoch 156/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - accuracy: 0.2932 - loss: 2.7563
# Epoch 157/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - accuracy: 0.3721 - loss: 2.5795
# Epoch 158/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 0.3535 - loss: 2.5891
# Epoch 159/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.3279 - loss: 2.6186
# Epoch 160/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.3303 - loss: 2.5917
# Epoch 161/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - accuracy: 0.3682 - loss: 2.5449
# Epoch 162/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.3569 - loss: 2.5546
# Epoch 163/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - accuracy: 0.3385 - loss: 2.6022
# Epoch 164/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.3502 - loss: 2.5690
# Epoch 165/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.3779 - loss: 2.4924
# Epoch 166/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3880 - loss: 2.4692
# Epoch 167/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - accuracy: 0.3755 - loss: 2.4612
# Epoch 168/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - accuracy: 0.3330 - loss: 2.5521
# Epoch 169/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - accuracy: 0.3816 - loss: 2.4605
# Epoch 170/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - accuracy: 0.4075 - loss: 2.4157
# Epoch 171/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - accuracy: 0.3741 - loss: 2.5036
# Epoch 172/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4152 - loss: 2.3785
# Epoch 173/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.4032 - loss: 2.3727
# Epoch 174/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - accuracy: 0.3883 - loss: 2.4130
# Epoch 175/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - accuracy: 0.4004 - loss: 2.3935
# Epoch 176/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - accuracy: 0.3799 - loss: 2.4099
# Epoch 177/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.3968 - loss: 2.3708
# Epoch 178/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.3923 - loss: 2.3709
# Epoch 179/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - accuracy: 0.4361 - loss: 2.2628
# Epoch 180/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - accuracy: 0.3790 - loss: 2.3739
# Epoch 181/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - accuracy: 0.4393 - loss: 2.2813
# Epoch 182/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - accuracy: 0.4086 - loss: 2.3228
# Epoch 183/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - accuracy: 0.4340 - loss: 2.2908
# Epoch 184/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - accuracy: 0.4010 - loss: 2.3063
# Epoch 185/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - accuracy: 0.4341 - loss: 2.3341
# Epoch 186/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - accuracy: 0.4387 - loss: 2.2407
# Epoch 187/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - accuracy: 0.4965 - loss: 2.2242
# Epoch 188/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - accuracy: 0.4360 - loss: 2.2529
# Epoch 189/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.4207 - loss: 2.2451
# Epoch 190/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - accuracy: 0.4326 - loss: 2.2688
# Epoch 191/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - accuracy: 0.4804 - loss: 2.1949
# Epoch 192/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - accuracy: 0.4260 - loss: 2.2320
# Epoch 193/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - accuracy: 0.4379 - loss: 2.1992
# Epoch 194/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - accuracy: 0.4712 - loss: 2.1498
# Epoch 195/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.4477 - loss: 2.2037
# Epoch 196/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 0.4578 - loss: 2.1368
# Epoch 197/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - accuracy: 0.4815 - loss: 2.0764
# Epoch 198/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.4543 - loss: 2.2108
# Epoch 199/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - accuracy: 0.4806 - loss: 2.1305
# Epoch 200/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - accuracy: 0.4912 - loss: 2.1249
# Epoch 201/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.4958 - loss: 2.1243
# Epoch 202/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - accuracy: 0.4629 - loss: 2.1188
# Epoch 203/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - accuracy: 0.4432 - loss: 2.1269
# Epoch 204/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - accuracy: 0.4748 - loss: 2.0656
# Epoch 205/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - accuracy: 0.5410 - loss: 2.0333
# Epoch 206/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - accuracy: 0.4743 - loss: 2.0916
# Epoch 207/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - accuracy: 0.5015 - loss: 2.0541
# Epoch 208/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5035 - loss: 2.0703
# Epoch 209/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - accuracy: 0.4918 - loss: 2.0530
# Epoch 210/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.4813 - loss: 2.0569
# Epoch 211/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - accuracy: 0.4361 - loss: 2.0840
# Epoch 212/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 0.4952 - loss: 1.9596
# Epoch 213/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - accuracy: 0.4934 - loss: 2.0265
# Epoch 214/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - accuracy: 0.5199 - loss: 1.9849
# Epoch 215/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.5154 - loss: 1.9922
# Epoch 216/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - accuracy: 0.5544 - loss: 1.9752
# Epoch 217/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - accuracy: 0.5197 - loss: 1.9692
# Epoch 218/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - accuracy: 0.5106 - loss: 1.9850
# Epoch 219/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - accuracy: 0.5321 - loss: 1.9480
# Epoch 220/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - accuracy: 0.5829 - loss: 1.9261
# Epoch 221/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - accuracy: 0.5599 - loss: 1.8762
# Epoch 222/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - accuracy: 0.5293 - loss: 1.9104
# Epoch 223/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - accuracy: 0.5609 - loss: 1.9222
# Epoch 224/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - accuracy: 0.5805 - loss: 1.8329
# Epoch 225/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 0.5948 - loss: 1.8699
# Epoch 226/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - accuracy: 0.5948 - loss: 1.7640
# Epoch 227/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - accuracy: 0.5529 - loss: 1.8788
# Epoch 228/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - accuracy: 0.5716 - loss: 1.8656
# Epoch 229/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - accuracy: 0.5846 - loss: 1.8368
# Epoch 230/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6225 - loss: 1.7808
# Epoch 231/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - accuracy: 0.5646 - loss: 1.8841
# Epoch 232/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - accuracy: 0.5733 - loss: 1.8253
# Epoch 233/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.6081 - loss: 1.8347
# Epoch 234/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - accuracy: 0.6217 - loss: 1.7928
# Epoch 235/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - accuracy: 0.6144 - loss: 1.7923
# Epoch 236/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.6077 - loss: 1.8242
# Epoch 237/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - accuracy: 0.5898 - loss: 1.8249
# Epoch 238/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - accuracy: 0.6236 - loss: 1.8077
# Epoch 239/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - accuracy: 0.6105 - loss: 1.7751
# Epoch 240/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.6306 - loss: 1.7409
# Epoch 241/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - accuracy: 0.6139 - loss: 1.7847
# Epoch 242/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6167 - loss: 1.7673
# Epoch 243/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - accuracy: 0.5963 - loss: 1.7912
# Epoch 244/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - accuracy: 0.6519 - loss: 1.6844
# Epoch 245/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - accuracy: 0.6184 - loss: 1.6995
# Epoch 246/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - accuracy: 0.6644 - loss: 1.6971
# Epoch 247/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - accuracy: 0.6192 - loss: 1.7521
# Epoch 248/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step - accuracy: 0.6439 - loss: 1.6751
# Epoch 249/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step - accuracy: 0.6186 - loss: 1.7605
# Epoch 250/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.6297 - loss: 1.6910
# Epoch 251/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - accuracy: 0.6439 - loss: 1.6626
# Epoch 252/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - accuracy: 0.6483 - loss: 1.6756
# Epoch 253/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - accuracy: 0.6164 - loss: 1.7060
# Epoch 254/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.6479 - loss: 1.6919
# Epoch 255/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - accuracy: 0.6632 - loss: 1.6280
# Epoch 256/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - accuracy: 0.6729 - loss: 1.6500
# Epoch 257/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - accuracy: 0.6602 - loss: 1.6099
# Epoch 258/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - accuracy: 0.6540 - loss: 1.5736
# Epoch 259/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - accuracy: 0.6561 - loss: 1.6918
# Epoch 260/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - accuracy: 0.6722 - loss: 1.5499
# Epoch 261/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - accuracy: 0.6597 - loss: 1.6377
# Epoch 262/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - accuracy: 0.6375 - loss: 1.6098
# Epoch 263/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.6403 - loss: 1.5657
# Epoch 264/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - accuracy: 0.6791 - loss: 1.5616
# Epoch 265/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - accuracy: 0.7020 - loss: 1.5316
# Epoch 266/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.6604 - loss: 1.5706
# Epoch 267/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6624 - loss: 1.5541
# Epoch 268/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - accuracy: 0.6801 - loss: 1.5285
# Epoch 269/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.6960 - loss: 1.5303
# Epoch 270/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.6789 - loss: 1.5542
# Epoch 271/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - accuracy: 0.6565 - loss: 1.5720
# Epoch 272/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - accuracy: 0.7211 - loss: 1.4521
# Epoch 273/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - accuracy: 0.7025 - loss: 1.5257
# Epoch 274/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - accuracy: 0.7150 - loss: 1.4474
# Epoch 275/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.7385 - loss: 1.4622
# Epoch 276/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - accuracy: 0.7252 - loss: 1.5127
# Epoch 277/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.6983 - loss: 1.4738
# Epoch 278/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - accuracy: 0.7231 - loss: 1.4155
# Epoch 279/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - accuracy: 0.7236 - loss: 1.4798
# Epoch 280/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.7326 - loss: 1.4389
# Epoch 281/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - accuracy: 0.7378 - loss: 1.4424
# Epoch 282/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - accuracy: 0.7435 - loss: 1.4433
# Epoch 283/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - accuracy: 0.7283 - loss: 1.4774
# Epoch 284/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7428 - loss: 1.3996
# Epoch 285/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.7294 - loss: 1.4704
# Epoch 286/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - accuracy: 0.7542 - loss: 1.4012
# Epoch 287/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - accuracy: 0.7126 - loss: 1.4580
# Epoch 288/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - accuracy: 0.7457 - loss: 1.4111
# Epoch 289/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - accuracy: 0.7241 - loss: 1.3949
# Epoch 290/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.7201 - loss: 1.4217
# Epoch 291/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.7665 - loss: 1.3671
# Epoch 292/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - accuracy: 0.7380 - loss: 1.3853
# Epoch 293/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - accuracy: 0.7559 - loss: 1.3457
# Epoch 294/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - accuracy: 0.7676 - loss: 1.3513
# Epoch 295/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.7677 - loss: 1.3695
# Epoch 296/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - accuracy: 0.7698 - loss: 1.3537
# Epoch 297/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.7598 - loss: 1.3382
# Epoch 298/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.7548 - loss: 1.3978
# Epoch 299/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.7556 - loss: 1.3504
# Epoch 300/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.7845 - loss: 1.3123
# Epoch 301/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - accuracy: 0.7954 - loss: 1.2876
# Epoch 302/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - accuracy: 0.7558 - loss: 1.3474
# Epoch 303/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - accuracy: 0.8002 - loss: 1.2534
# Epoch 304/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.7869 - loss: 1.3362
# Epoch 305/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.8148 - loss: 1.2738
# Epoch 306/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - accuracy: 0.7562 - loss: 1.3091
# Epoch 307/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - accuracy: 0.8117 - loss: 1.2505
# Epoch 308/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - accuracy: 0.7829 - loss: 1.3105
# Epoch 309/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - accuracy: 0.7931 - loss: 1.2820
# Epoch 310/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 0.8104 - loss: 1.2819
# Epoch 311/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - accuracy: 0.8257 - loss: 1.2185
# Epoch 312/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - accuracy: 0.8200 - loss: 1.2960
# Epoch 313/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - accuracy: 0.8185 - loss: 1.2589
# Epoch 314/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - accuracy: 0.8410 - loss: 1.2151
# Epoch 315/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.8146 - loss: 1.2219
# Epoch 316/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - accuracy: 0.7949 - loss: 1.2425
# Epoch 317/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - accuracy: 0.7829 - loss: 1.2443
# Epoch 318/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - accuracy: 0.8315 - loss: 1.1961
# Epoch 319/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - accuracy: 0.8467 - loss: 1.1695
# Epoch 320/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - accuracy: 0.8381 - loss: 1.1723
# Epoch 321/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - accuracy: 0.8552 - loss: 1.1794
# Epoch 322/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - accuracy: 0.8186 - loss: 1.1880
# Epoch 323/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - accuracy: 0.8302 - loss: 1.1889
# Epoch 324/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - accuracy: 0.8242 - loss: 1.1792
# Epoch 325/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - accuracy: 0.8273 - loss: 1.1951
# Epoch 326/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - accuracy: 0.8293 - loss: 1.1588
# Epoch 327/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.8086 - loss: 1.1776
# Epoch 328/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - accuracy: 0.8130 - loss: 1.1801
# Epoch 329/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - accuracy: 0.8280 - loss: 1.1186
# Epoch 330/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.8154 - loss: 1.2062
# Epoch 331/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - accuracy: 0.8444 - loss: 1.1510
# Epoch 332/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - accuracy: 0.8372 - loss: 1.0866
# Epoch 333/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - accuracy: 0.8512 - loss: 1.1138
# Epoch 334/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - accuracy: 0.8511 - loss: 1.0743
# Epoch 335/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - accuracy: 0.8481 - loss: 1.1278
# Epoch 336/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.8609 - loss: 1.0944
# Epoch 337/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - accuracy: 0.8410 - loss: 1.1311
# Epoch 338/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - accuracy: 0.8684 - loss: 1.1057
# Epoch 339/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - accuracy: 0.8830 - loss: 1.0762
# Epoch 340/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - accuracy: 0.8694 - loss: 1.1126
# Epoch 341/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - accuracy: 0.8462 - loss: 1.0701
# Epoch 342/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - accuracy: 0.8614 - loss: 1.0723
# Epoch 343/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - accuracy: 0.8647 - loss: 1.0893
# Epoch 344/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - accuracy: 0.8704 - loss: 1.0770
# Epoch 345/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - accuracy: 0.8761 - loss: 1.0483
# Epoch 346/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.8414 - loss: 1.0751
# Epoch 347/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - accuracy: 0.8661 - loss: 1.0363
# Epoch 348/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - accuracy: 0.8621 - loss: 1.0639
# Epoch 349/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.8901 - loss: 1.0480
# Epoch 350/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - accuracy: 0.8752 - loss: 1.0454
# Epoch 351/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.8947 - loss: 1.0339
# Epoch 352/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - accuracy: 0.8931 - loss: 1.0225
# Epoch 353/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - accuracy: 0.8826 - loss: 1.0072
# Epoch 354/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - accuracy: 0.8949 - loss: 1.0354
# Epoch 355/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - accuracy: 0.8645 - loss: 1.0221
# Epoch 356/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8971 - loss: 1.0031
# Epoch 357/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - accuracy: 0.8903 - loss: 0.9827
# Epoch 358/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - accuracy: 0.9186 - loss: 0.9439
# Epoch 359/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - accuracy: 0.8888 - loss: 1.0033
# Epoch 360/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - accuracy: 0.9088 - loss: 0.9657
# Epoch 361/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.8760 - loss: 0.9653
# Epoch 362/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.8943 - loss: 1.0001
# Epoch 363/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - accuracy: 0.8965 - loss: 0.9863
# Epoch 364/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - accuracy: 0.9037 - loss: 0.9423
# Epoch 365/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - accuracy: 0.9106 - loss: 0.9719
# Epoch 366/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - accuracy: 0.8792 - loss: 0.9415
# Epoch 367/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - accuracy: 0.8453 - loss: 1.0309
# Epoch 368/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.8740 - loss: 0.9777
# Epoch 369/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.9067 - loss: 0.9705
# Epoch 370/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - accuracy: 0.9103 - loss: 0.9426
# Epoch 371/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.9009 - loss: 0.9569
# Epoch 372/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - accuracy: 0.9050 - loss: 0.9195
# Epoch 373/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - accuracy: 0.8997 - loss: 0.9459
# Epoch 374/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - accuracy: 0.9156 - loss: 0.9328
# Epoch 375/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - accuracy: 0.9084 - loss: 0.8942
# Epoch 376/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - accuracy: 0.9025 - loss: 0.9285
# Epoch 377/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - accuracy: 0.9189 - loss: 0.8900
# Epoch 378/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step - accuracy: 0.9164 - loss: 0.8850
# Epoch 379/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - accuracy: 0.9184 - loss: 0.9310
# Epoch 380/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - accuracy: 0.8686 - loss: 0.9395
# Epoch 381/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - accuracy: 0.9158 - loss: 0.8718
# Epoch 382/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.9063 - loss: 0.8938
# Epoch 383/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - accuracy: 0.9022 - loss: 0.9047
# Epoch 384/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - accuracy: 0.9193 - loss: 0.8619
# Epoch 385/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - accuracy: 0.9072 - loss: 0.8359
# Epoch 386/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - accuracy: 0.9153 - loss: 0.8853
# Epoch 387/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - accuracy: 0.9062 - loss: 0.8511
# Epoch 388/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - accuracy: 0.9083 - loss: 0.8532
# Epoch 389/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9223 - loss: 0.8719
# Epoch 390/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.9260 - loss: 0.8319
# Epoch 391/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - accuracy: 0.9292 - loss: 0.8374
# Epoch 392/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - accuracy: 0.9167 - loss: 0.8543
# Epoch 393/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - accuracy: 0.9370 - loss: 0.8017
# Epoch 394/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - accuracy: 0.9280 - loss: 0.8060
# Epoch 395/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - accuracy: 0.9501 - loss: 0.8146
# Epoch 396/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step - accuracy: 0.9332 - loss: 0.8540
# Epoch 397/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - accuracy: 0.9608 - loss: 0.8179
# Epoch 398/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.9242 - loss: 0.8520
# Epoch 399/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - accuracy: 0.9486 - loss: 0.8099
# Epoch 400/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - accuracy: 0.9362 - loss: 0.8016
# Epoch 401/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.9310 - loss: 0.8036
# Epoch 402/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - accuracy: 0.9484 - loss: 0.8014
# Epoch 403/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.9251 - loss: 0.8168
# Epoch 404/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - accuracy: 0.9451 - loss: 0.8076
# Epoch 405/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - accuracy: 0.9558 - loss: 0.7904
# Epoch 406/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9409 - loss: 0.7760
# Epoch 407/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - accuracy: 0.9466 - loss: 0.8182
# Epoch 408/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - accuracy: 0.9457 - loss: 0.7816
# Epoch 409/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.9388 - loss: 0.7734
# Epoch 410/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - accuracy: 0.9573 - loss: 0.7234
# Epoch 411/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.9473 - loss: 0.7648
# Epoch 412/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - accuracy: 0.9463 - loss: 0.7910
# Epoch 413/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - accuracy: 0.9497 - loss: 0.7431
# Epoch 414/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step - accuracy: 0.9592 - loss: 0.7718
# Epoch 415/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - accuracy: 0.9404 - loss: 0.7804
# Epoch 416/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - accuracy: 0.9479 - loss: 0.7547
# Epoch 417/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - accuracy: 0.9333 - loss: 0.7393
# Epoch 418/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - accuracy: 0.9491 - loss: 0.7626
# Epoch 419/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.9542 - loss: 0.7338
# Epoch 420/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - accuracy: 0.9489 - loss: 0.7617
# Epoch 421/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - accuracy: 0.9691 - loss: 0.7371
# Epoch 422/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.9615 - loss: 0.7002
# Epoch 423/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - accuracy: 0.9528 - loss: 0.7584
# Epoch 424/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - accuracy: 0.9632 - loss: 0.6889
# Epoch 425/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - accuracy: 0.9450 - loss: 0.7163
# Epoch 426/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.9676 - loss: 0.7099
# Epoch 427/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - accuracy: 0.9534 - loss: 0.7045
# Epoch 428/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - accuracy: 0.9552 - loss: 0.7094
# Epoch 429/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9656 - loss: 0.7070
# Epoch 430/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.9697 - loss: 0.7286
# Epoch 431/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - accuracy: 0.9464 - loss: 0.7294
# Epoch 432/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - accuracy: 0.9653 - loss: 0.7157
# Epoch 433/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - accuracy: 0.9561 - loss: 0.6632
# Epoch 434/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - accuracy: 0.9732 - loss: 0.6664
# Epoch 435/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9625 - loss: 0.6882
# Epoch 436/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 0.9697 - loss: 0.6468
# Epoch 437/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - accuracy: 0.9722 - loss: 0.6512
# Epoch 438/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - accuracy: 0.9719 - loss: 0.6403
# Epoch 439/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - accuracy: 0.9675 - loss: 0.6690
# Epoch 440/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - accuracy: 0.9559 - loss: 0.6970
# Epoch 441/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - accuracy: 0.9645 - loss: 0.6650
# Epoch 442/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - accuracy: 0.9671 - loss: 0.6872
# Epoch 443/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - accuracy: 0.9600 - loss: 0.6554
# Epoch 444/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - accuracy: 0.9608 - loss: 0.6350
# Epoch 445/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - accuracy: 0.9578 - loss: 0.6473
# Epoch 446/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - accuracy: 0.9578 - loss: 0.6513
# Epoch 447/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - accuracy: 0.9719 - loss: 0.6438
# Epoch 448/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - accuracy: 0.9685 - loss: 0.6242
# Epoch 449/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - accuracy: 0.9786 - loss: 0.6394
# Epoch 450/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - accuracy: 0.9637 - loss: 0.6467
# Epoch 451/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.9717 - loss: 0.6189
# Epoch 452/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - accuracy: 0.9599 - loss: 0.6369
# Epoch 453/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.9790 - loss: 0.5984
# Epoch 454/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - accuracy: 0.9516 - loss: 0.6310
# Epoch 455/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - accuracy: 0.9715 - loss: 0.6327
# Epoch 456/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - accuracy: 0.9611 - loss: 0.6178
# Epoch 457/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.9633 - loss: 0.6208
# Epoch 458/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - accuracy: 0.9595 - loss: 0.5905
# Epoch 459/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - accuracy: 0.9637 - loss: 0.6059
# Epoch 460/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - accuracy: 0.9662 - loss: 0.6163
# Epoch 461/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9619 - loss: 0.6147
# Epoch 462/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step - accuracy: 0.9726 - loss: 0.5771
# Epoch 463/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - accuracy: 0.9671 - loss: 0.5930
# Epoch 464/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.9642 - loss: 0.6187
# Epoch 465/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - accuracy: 0.9787 - loss: 0.5490
# Epoch 466/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - accuracy: 0.9646 - loss: 0.5729
# Epoch 467/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - accuracy: 0.9754 - loss: 0.5917
# Epoch 468/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - accuracy: 0.9871 - loss: 0.5776
# Epoch 469/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - accuracy: 0.9790 - loss: 0.5799
# Epoch 470/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step - accuracy: 0.9750 - loss: 0.5540
# Epoch 471/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.9813 - loss: 0.5486
# Epoch 472/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.9862 - loss: 0.5753
# Epoch 473/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - accuracy: 0.9644 - loss: 0.5602
# Epoch 474/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9678 - loss: 0.5522
# Epoch 475/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - accuracy: 0.9852 - loss: 0.5200
# Epoch 476/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - accuracy: 0.9850 - loss: 0.5414
# Epoch 477/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - accuracy: 0.9703 - loss: 0.5607
# Epoch 478/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.9767 - loss: 0.5457
# Epoch 479/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - accuracy: 0.9820 - loss: 0.5350
# Epoch 480/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - accuracy: 0.9699 - loss: 0.5388
# Epoch 481/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - accuracy: 0.9699 - loss: 0.5392
# Epoch 482/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - accuracy: 0.9544 - loss: 0.5599
# Epoch 483/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - accuracy: 0.9753 - loss: 0.5357
# Epoch 484/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - accuracy: 0.9908 - loss: 0.4997
# Epoch 485/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.9657 - loss: 0.5444
# Epoch 486/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step - accuracy: 0.9684 - loss: 0.5125
# Epoch 487/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.9608 - loss: 0.5243
# Epoch 488/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.9900 - loss: 0.5063
# Epoch 489/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - accuracy: 0.9745 - loss: 0.5053
# Epoch 490/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 0.9769 - loss: 0.5147
# Epoch 491/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - accuracy: 0.9765 - loss: 0.5076
# Epoch 492/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - accuracy: 0.9760 - loss: 0.4936
# Epoch 493/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - accuracy: 0.9776 - loss: 0.5030
# Epoch 494/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - accuracy: 0.9837 - loss: 0.4976
# Epoch 495/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - accuracy: 0.9755 - loss: 0.5192
# Epoch 496/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - accuracy: 0.9760 - loss: 0.5159
# Epoch 497/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - accuracy: 0.9790 - loss: 0.4980
# Epoch 498/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step - accuracy: 0.9808 - loss: 0.4815
# Epoch 499/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - accuracy: 0.9901 - loss: 0.4779
# Epoch 500/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.9831 - loss: 0.4859

# %% [markdown]
# # Predicting a Word Using the Trained CBOW Model

# %% [markdown]
# In this step, we define a function to predict a word based on a given context using the trained CBOW model.
#
# 1. **Function: `predict_word`**:
#    - **Input**: The function takes a list of context words as input. The number of context words should match the expected size (2 times the window size).
#    - **Context sequence conversion**: The input context words are tokenized into a sequence of integers using the same tokenizer that was used during training.
#    - **Input validation**: The function checks whether the length of the context sequence matches the expected size (2 times the window size). If not, it prints an error message.
#    - **Prediction**: The tokenized context is fed into the trained CBOW model, which predicts the probability distribution over the vocabulary.
#    - **Retrieve predicted word**: The predicted word is the one with the highest probability. The function retrieves the word corresponding to the predicted index from the tokenizer's word index.
#
# 2. **Example**:
#    - We provide a sample context: `['الحادث', 'بسبب', 'مزدحم', 'الطريق']`.
#    - The function predicts the word that fits best in this context, based on the model's learned weights.
#    - The predicted word is printed along with the input context.
#
# This function allows us to test the CBOW model by predicting words based on their surrounding context from the corpus.

# %%
#this has been solved multiple times in labs and practic over the weekend


def predict_word(context_words, model, tokenizer, window_size):
    context_sequence = tokenizer.texts_to_sequences([context_words])[0]
    
    expected_length = 2 * window_size
    if len(context_sequence) != expected_length:
        print(f"Error: Expected {expected_length} context words, got {len(context_sequence)}.")
        return None
    
    context_sequence = np.array(context_sequence).reshape(1, -1)
    print(context_sequence)
    prediction = model.predict(context_sequence)
    
    predicted_word_index = np.argmax(prediction)
    
    predicted_word = tokenizer.index_word.get(predicted_word_index, "Unknown")
    
    print(f"Context: {context_words}")
    print(f"Predicted word: {predicted_word}")
    
    return predicted_word

# %%
#this has been solved multiple times in labs and practic over the weekend


context_words =['الحادث', 'بسبب', 'مزدحم', 'الطريق']
model.load_weights('cbow_model.weights.h5')
predicted_word = predict_word(context_words, model, tokenizer, window_size=2)
# Out:
# [[47  4 19  3]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Context: ['الحادث', 'بسبب', 'مزدحم', 'الطريق']
# Predicted word: اليوم

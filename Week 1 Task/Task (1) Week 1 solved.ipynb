# %% [markdown]
# #Dataset Description

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/Othercomputers/My Mac/Data Science/Data set/Task (1) Dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.isna().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %% [markdown]
# ### Handle Missing Values

# %%
df = df.drop(['Defect_of_vehicle','Service_year_of_vehicle','Work_of_casuality','Fitness_of_casuality'],axis=1)

# %%
df.isna().sum()
# Out:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Educational_level              741
# Vehicle_driver_relation        579
# Driving_experience             829
# Type_of_vehicle                950
# Owner_of_vehicle               482
# Area_accident_occured          239
# Lanes_or_Medians               385
# Road_allignment                142
# Types_of_Junction              887
# Road_surface_type              172
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision              155
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Vehicle_movement               308
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Pedestrian_movement              0
# Cause_of_accident                0
# ...

# %%
df['Educational_level'] = df['Educational_level'].fillna(df['Educational_level'].mode()[0])

# %%
df['Vehicle_driver_relation'] = df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mode()[0])

# %%
Driving_experience_test = df['Driving_experience'].mode()
Driving_experience_test
# Out:
# 0    5-10yr
# Name: Driving_experience, dtype: object

# %%
df['Driving_experience'] = df['Driving_experience'].fillna(df['Driving_experience'].mode()[0])

# %%
df.dropna(subset=['Road_allignment'], inplace=True)

# %%
df['Road_surface_type']
# Out:
# 0        Asphalt roads
# 1        Asphalt roads
# 3          Earth roads
# 4        Asphalt roads
# 6                  NaN
#              ...
# 12311    Asphalt roads
# 12312    Asphalt roads
# 12313    Asphalt roads
# 12314    Asphalt roads
# 12315    Asphalt roads
# Name: Road_surface_type, Length: 12174, dtype: object

# %%
df['Road_surface_type'].mode()
# Out:
# 0    Asphalt roads
# Name: Road_surface_type, dtype: object

# %%
df['Road_surface_type'] = df['Road_surface_type'].fillna(df['Road_surface_type'].mode()[0])

# %%
df.isna().sum()
# Out:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Educational_level                0
# Vehicle_driver_relation          0
# Driving_experience               0
# Type_of_vehicle                933
# Owner_of_vehicle               428
# Area_accident_occured          217
# Lanes_or_Medians               363
# Road_allignment                  0
# Types_of_Junction              880
# Road_surface_type                0
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision              155
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Vehicle_movement               305
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Pedestrian_movement              0
# Cause_of_accident                0
# ...

# %%
df['Type_of_collision']
# Out:
# 0        Collision with roadside-parked vehicles
# 1                 Vehicle with vehicle collision
# 3                 Vehicle with vehicle collision
# 4                 Vehicle with vehicle collision
# 6                 Vehicle with vehicle collision
#                           ...
# 12311             Vehicle with vehicle collision
# 12312             Vehicle with vehicle collision
# 12313             Vehicle with vehicle collision
# 12314             Vehicle with vehicle collision
# 12315             Vehicle with vehicle collision
# Name: Type_of_collision, Length: 12174, dtype: object

# %%
df['Type_of_collision'].mode()
# Out:
# 0    Vehicle with vehicle collision
# Name: Type_of_collision, dtype: object

# %%
df['Type_of_collision']= df['Type_of_collision'].fillna(df['Type_of_collision'].mode()[0])

# %%
df.isna().sum()
# Out:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Educational_level                0
# Vehicle_driver_relation          0
# Driving_experience               0
# Type_of_vehicle                933
# Owner_of_vehicle               428
# Area_accident_occured          217
# Lanes_or_Medians               363
# Road_allignment                  0
# Types_of_Junction              880
# Road_surface_type                0
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision                0
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Vehicle_movement               305
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Pedestrian_movement              0
# Cause_of_accident                0
# ...

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Area_accident_occured',
#        'Lanes_or_Medians', 'Road_allignment', 'Types_of_Junction',
#        'Road_surface_type', 'Road_surface_conditions', 'Light_conditions',
#        'Weather_conditions', 'Type_of_collision',
#        'Number_of_vehicles_involved', 'Number_of_casualties',
#        'Vehicle_movement', 'Casualty_class', 'Sex_of_casualty',
#        'Age_band_of_casualty', 'Casualty_severity', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
df[['Type_of_vehicle','Owner_of_vehicle','Area_accident_occured','Lanes_or_Medians','Types_of_Junction','Vehicle_movement']]
# Out:
#            Type_of_vehicle Owner_of_vehicle Area_accident_occured  \
# 0               Automobile            Owner     Residential areas
# 1      Public (> 45 seats)            Owner          Office areas
# 3      Public (> 45 seats)     Governmental          Office areas
# 4                      NaN            Owner      Industrial areas
# 6               Automobile            Owner     Residential areas
# ...                    ...              ...                   ...
# 12311       Lorry (11?40Q)            Owner   Outside rural areas
# 12312           Automobile            Owner   Outside rural areas
# 12313                Bajaj            Owner   Outside rural areas
# 12314      Lorry (41?100Q)            Owner          Office areas
# 12315                Other            Owner   Outside rural areas
#
#                                        Lanes_or_Medians Types_of_Junction  \
# 0                                                   NaN       No junction
# ...

# %%
Type_of_junction_count = df['Types_of_Junction'].value_counts()
Type_of_junction_count
# Out:
# Types_of_Junction
# Y Shape        4495
# No junction    3793
# Crossing       2145
# Other           435
# Unknown         191
# O Shape         163
# T Shape          60
# X Shape          12
# Name: count, dtype: int64

# %%
Owner_of_Vehicle_count = df['Owner_of_vehicle'].value_counts()
Owner_of_Vehicle_count
# Out:
# Owner_of_vehicle
# Owner           10389
# Governmental     1023
# Organization      312
# Other              22
# Name: count, dtype: int64

# %%
Area_accident_occured_count = df['Area_accident_occured'].value_counts()
Area_accident_occured_count
# Out:
# Area_accident_occured
# Other                              3809
# Office areas                       3440
# Residential areas                  2020
#  Church areas                      1060
#  Industrial areas                   429
# School areas                        415
#   Recreational areas                305
#  Outside rural areas                218
#  Hospital areas                     111
#   Market areas                       63
# Rural village areas                  44
# Unknown                              22
# Rural village areasOffice areas      20
# Recreational areas                    1
# Name: count, dtype: int64

# %%
df['Owner_of_vehicle']= df['Owner_of_vehicle'].fillna(df['Owner_of_vehicle'].mode()[0])

# %%
Vehicle_movement_count = df['Vehicle_movement'].value_counts()
Vehicle_movement_count
# Out:
# Vehicle_movement
# Going straight         8066
# Moving Backward         971
# Other                   919
# Reversing               558
# Turnover                487
# Getting off             337
# Entering a junction     190
# Overtaking               96
# Unknown                  87
# Stopping                 61
# U-Turn                   49
# Waiting to go            39
# Parked                    9
# Name: count, dtype: int64

# %%
df['Vehicle_movement']= df['Vehicle_movement'].fillna(df['Vehicle_movement'].mode()[0])

# %%
df.isna().sum()
# Out:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Educational_level                0
# Vehicle_driver_relation          0
# Driving_experience               0
# Type_of_vehicle                933
# Owner_of_vehicle                 0
# Area_accident_occured          217
# Lanes_or_Medians               363
# Road_allignment                  0
# Types_of_Junction              880
# Road_surface_type                0
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision                0
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Vehicle_movement                 0
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Pedestrian_movement              0
# Cause_of_accident                0
# ...

# %%
Lanes_or_Medians_count = df['Lanes_or_Medians'].value_counts()
Lanes_or_Medians_count
# Out:
# Lanes_or_Medians
# Two-way (divided with broken lines road marking)    4356
# Undivided Two way                                   3796
# other                                               1616
# Double carriageway (median)                         1020
# One way                                              824
# Two-way (divided with solid lines road marking)      142
# Unknown                                               57
# Name: count, dtype: int64

# %%
df.dropna(subset=['Lanes_or_Medians'], inplace=True)

# %%
df.dropna(subset=['Area_accident_occured'], inplace=True)

# %%
df.isna().sum()
# Out:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Educational_level                0
# Vehicle_driver_relation          0
# Driving_experience               0
# Type_of_vehicle                870
# Owner_of_vehicle                 0
# Area_accident_occured            0
# Lanes_or_Medians                 0
# Road_allignment                  0
# Types_of_Junction              844
# Road_surface_type                0
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision                0
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Vehicle_movement                 0
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Pedestrian_movement              0
# Cause_of_accident                0
# ...

# %%
Type_of_junction_count = df['Types_of_Junction'].value_counts()
Type_of_junction_count
# Out:
# Types_of_Junction
# Y Shape        4292
# No junction    3642
# Crossing       2038
# Other           407
# Unknown         183
# O Shape         154
# T Shape          54
# X Shape          12
# Name: count, dtype: int64

# %%
Type_of_vehicle_count = df['Type_of_vehicle'].value_counts()
Type_of_vehicle_count
# Out:
# Type_of_vehicle
# Automobile              3032
# Lorry (41?100Q)         2061
# Other                   1142
# Pick up upto 10Q         778
# Public (12 seats)        661
# Stationwagen             647
# Public (13?45 seats)     512
# Lorry (11?40Q)           509
# Public (> 45 seats)      382
# Long lorry               356
# Taxi                     253
# Motorcycle               174
# Special vehicle           83
# Ridden horse              72
# Turbo                     45
# Bajaj                     28
# Bicycle                   21
# Name: count, dtype: int64

# %%
df['Type_of_vehicle']= df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode()[0])

# %%
df['Types_of_Junction']= df['Types_of_Junction'].fillna(df['Types_of_Junction'].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11626 entries, 1 to 12315
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         11626 non-null  object
#  1   Day_of_week                  11626 non-null  object
#  2   Age_band_of_driver           11626 non-null  object
#  3   Sex_of_driver                11626 non-null  object
#  4   Educational_level            11626 non-null  object
#  5   Vehicle_driver_relation      11626 non-null  object
#  6   Driving_experience           11626 non-null  object
#  7   Type_of_vehicle              11626 non-null  object
#  8   Owner_of_vehicle             11626 non-null  object
#  9   Area_accident_occured        11626 non-null  object
#  10  Lanes_or_Medians             11626 non-null  object
#  11  Road_allignment              11626 non-null  object
#  12  Types_of_Junction            11626 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df['Type_of_vehicle'].value_counts()
# Out:
# Type_of_vehicle
# Automobile              3902
# Lorry (41?100Q)         2061
# Other                   1142
# Pick up upto 10Q         778
# Public (12 seats)        661
# Stationwagen             647
# Public (13?45 seats)     512
# Lorry (11?40Q)           509
# Public (> 45 seats)      382
# Long lorry               356
# Taxi                     253
# Motorcycle               174
# Special vehicle           83
# Ridden horse              72
# Turbo                     45
# Bajaj                     28
# Bicycle                   21
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Area_accident_occured',
#        'Lanes_or_Medians', 'Road_allignment', 'Types_of_Junction',
#        'Road_surface_type', 'Road_surface_conditions', 'Light_conditions',
#        'Weather_conditions', 'Type_of_collision',
#        'Number_of_vehicles_involved', 'Number_of_casualties',
#        'Vehicle_movement', 'Casualty_class', 'Sex_of_casualty',
#        'Age_band_of_casualty', 'Casualty_severity', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
df['Day_of_week'].value_counts()
# Out:
# Day_of_week
# Friday       1920
# Thursday     1736
# Wednesday    1735
# Tuesday      1677
# Saturday     1587
# Monday       1586
# Sunday       1385
# Name: count, dtype: int64

# %%
df['Age_band_of_driver'].value_counts()
# Out:
# Age_band_of_driver
# 18-30       4016
# 31-50       3878
# Over 51     1484
# Unknown     1464
# Under 18     784
# Name: count, dtype: int64

# %%
df['Time'].value_counts()
# Out:
# Time
# 15:30:00    115
# 17:10:00    106
# 18:30:00     98
# 11:30:00     95
# 18:00:00     93
#            ...
# 11:53:00      1
# 1:32:00       1
# 4:49:00       1
# 23:19:00      1
# 2:47:00       1
# Name: count, Length: 1068, dtype: int64

# %%
pd.to_datetime

# %%
df['Sex_of_driver'].value_counts()
# Out:
# Sex_of_driver
# Male       10807
# Female       654
# Unknown      165
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
test_time = pd.to_timedelta(df['Time'])
test_time
# Out:
# 1       0 days 17:02:00
# 3       0 days 01:06:00
# 4       0 days 01:06:00
# 6       0 days 17:30:00
# 7       0 days 17:20:00
#               ...
# 12311   0 days 16:15:00
# 12312   0 days 18:00:00
# 12313   0 days 13:55:00
# 12314   0 days 13:55:00
# 12315   0 days 13:55:00
# Name: Time, Length: 11626, dtype: timedelta64[ns]

# %%
df['Time'] = pd.to_timedelta(df['Time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11626 entries, 1 to 12315
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         11626 non-null  timedelta64[ns]
#  1   Day_of_week                  11626 non-null  object
#  2   Age_band_of_driver           11626 non-null  object
#  3   Sex_of_driver                11626 non-null  object
#  4   Educational_level            11626 non-null  object
#  5   Vehicle_driver_relation      11626 non-null  object
#  6   Driving_experience           11626 non-null  object
#  7   Type_of_vehicle              11626 non-null  object
#  8   Owner_of_vehicle             11626 non-null  object
#  9   Area_accident_occured        11626 non-null  object
#  10  Lanes_or_Medians             11626 non-null  object
#  11  Road_allignment              11626 non-null  object
# ...

# %%
df['Sex_of_casualty'].value_counts()
# Out:
# Sex_of_casualty
# Male      4945
# na        4189
# Female    2492
# Name: count, dtype: int64

# %%
df['Vehicle_movement']
# Out:
# 1         Going straight
# 3         Going straight
# 4         Going straight
# 6        Moving Backward
# 7                 U-Turn
#               ...
# 12311     Going straight
# 12312              Other
# 12313              Other
# 12314              Other
# 12315           Stopping
# Name: Vehicle_movement, Length: 11626, dtype: object

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11626 entries, 1 to 12315
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         11626 non-null  timedelta64[ns]
#  1   Day_of_week                  11626 non-null  object
#  2   Age_band_of_driver           11626 non-null  object
#  3   Sex_of_driver                11626 non-null  object
#  4   Educational_level            11626 non-null  object
#  5   Vehicle_driver_relation      11626 non-null  object
#  6   Driving_experience           11626 non-null  object
#  7   Type_of_vehicle              11626 non-null  object
#  8   Owner_of_vehicle             11626 non-null  object
#  9   Area_accident_occured        11626 non-null  object
#  10  Lanes_or_Medians             11626 non-null  object
#  11  Road_allignment              11626 non-null  object
# ...

# %%
df['Number_of_vehicles_involved'].max()
# Out:
# 7

# %%
df['Number_of_casualties'].max()
# Out:
# 8

# %%
df['Age_band_of_driver'].mode()
# Out:
# 0    18-30
# Name: Age_band_of_driver, dtype: object

# %%
df['Sex_of_driver'].value_counts()
# Out:
# Sex_of_driver
# Male       10807
# Female       654
# Unknown      165
# Name: count, dtype: int64

# %%
df.head()
# Out:
#              Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 1 0 days 17:02:00      Monday              31-50          Male
# 3 0 days 01:06:00      Sunday              18-30          Male
# 4 0 days 01:06:00      Sunday              18-30          Male
# 6 0 days 17:30:00   Wednesday              18-30          Male
# 7 0 days 17:20:00      Friday              18-30          Male
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 1  Junior high school                Employee         Above 10yr
# 3  Junior high school                Employee             5-10yr
# 4  Junior high school                Employee              2-5yr
# 6  Junior high school                Employee              2-5yr
# 7  Junior high school                Employee              2-5yr
#
#        Type_of_vehicle Owner_of_vehicle Area_accident_occured  ...  \
# 1  Public (> 45 seats)            Owner          Office areas  ...
# ...

# %%
df.tail()
# Out:
#                  Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311 0 days 16:15:00   Wednesday              31-50          Male
# 12312 0 days 18:00:00      Sunday            Unknown          Male
# 12313 0 days 13:55:00      Sunday            Over 51          Male
# 12314 0 days 13:55:00      Sunday              18-30        Female
# 12315 0 days 13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311  Junior high school                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Area_accident_occured  ...  \
# 12311   Lorry (11?40Q)            Owner   Outside rural areas  ...
# ...

# %%
df.describe()
# Out:
#                             Time  Number_of_vehicles_involved  \
# count                      11626                 11626.000000
# mean   0 days 14:18:11.472561500                     2.041631
# std    0 days 05:11:39.653276274                     0.690573
# min              0 days 00:01:00                     1.000000
# 25%              0 days 10:31:00                     2.000000
# 50%              0 days 15:10:00                     2.000000
# 75%              0 days 18:10:00                     2.000000
# max              0 days 23:59:00                     7.000000
#
#        Number_of_casualties
# count          11626.000000
# mean               1.550834
# std                1.010757
# min                1.000000
# 25%                1.000000
# 50%                1.000000
# 75%                2.000000
# max                8.000000

# %%
numerical_columns = df[['Number_of_vehicles_involved','Number_of_casualties']]

correlation_natrix = numerical_columns.corr()

correlation_natrix
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                     1.000000              0.214609
# Number_of_casualties                            0.214609              1.000000

# %%
df['Accident_severity'].value_counts()
# Out:
# Accident_severity
# Slight Injury     9827
# Serious Injury    1651
# Fatal injury       148
# Name: count, dtype: int64

# %%
df.iloc[110]
# Out:
# Time                                           0 days 01:15:00
# Day_of_week                                           Saturday
# Age_band_of_driver                                     Unknown
# Sex_of_driver                                           Female
# Educational_level                           Junior high school
# Vehicle_driver_relation                               Employee
# Driving_experience                                  Above 10yr
# Type_of_vehicle                                     Automobile
# Owner_of_vehicle                                         Owner
# Area_accident_occured                             Market areas
# Lanes_or_Medians                             Undivided Two way
# Road_allignment                 Tangent road with flat terrain
# Types_of_Junction                                     Crossing
# Road_surface_type                                Asphalt roads
# Road_surface_conditions                                    Dry
# ...

# %%
df.iloc[110:120]
# Out:
#                Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 118 0 days 01:15:00    Saturday            Unknown        Female
# 119 0 days 01:15:00    Saturday              18-30       Unknown
# 120 0 days 01:15:00    Saturday              18-30          Male
# 122 0 days 18:30:00   Wednesday              31-50          Male
# 123 0 days 18:30:00   Wednesday              18-30          Male
# 125 0 days 15:52:00      Friday              31-50          Male
# 126 0 days 15:52:00      Friday              18-30          Male
# 127 0 days 12:33:00     Tuesday              18-30          Male
# 128 0 days 08:59:00      Monday           Under 18       Unknown
# 129 0 days 08:59:00      Monday            Over 51          Male
#
#       Educational_level Vehicle_driver_relation Driving_experience  \
# 118  Junior high school                Employee         Above 10yr
# 119   Elementary school                Employee          Below 1yr
# ...

# %%
Grouped_data = df.groupby('Sex_of_driver').agg(
    Average_vehicles_involved = ('Number_of_vehicles_involved','mean')
)

Grouped_data
# Out:
#                Average_vehicles_involved
# Sex_of_driver
# Female                          2.152905
# Male                            2.035810
# Unknown                         1.981818

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=df ,x='Sex_of_driver', y='Number_of_vehicles_involved')
plt.xlabel='Number of Car Involved'
plt.ylabel='Sex of Driver'
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df ,x='Number_of_vehicles_involved', y='Number_of_casualties')
plt.xlabel='Number of Car Involved'
plt.ylabel='Cansualties'
plt.show()

# %%
df['Pedestrian_movement'].value_counts()
# Out:
# Pedestrian_movement
# Not a Pedestrian                                                                                                                         10758
# Crossing from nearside - masked by parked or statioNot a Pedestrianry vehicle                                                              318
# Unknown or other                                                                                                                           276
# Crossing from driver's nearside                                                                                                            129
# Crossing from offside - masked by  parked or statioNot a Pedestrianry vehicle                                                               66
# In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing)                                                              43
# ...

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
Injuries_counts = df['Accident_severity'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(Injuries_counts, labels=Injuries_counts.index)
plt.title('Distribution of Injuries Type')
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
df['Accident_severity'].value_counts()
# Out:
# Accident_severity
# Slight Injury     9827
# Serious Injury    1651
# Fatal injury       148
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df ,x='Day_of_week', y='Number_of_vehicles_involved', hue='Accident_severity')
plt.xlabel='Number of Car Involved'
plt.ylabel='Sex of Driver'
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
count_of_severity = df['Accident_severity'].value_counts()

count_of_severity
# Out:
# Accident_severity
# Slight Injury     9827
# Serious Injury    1651
# Fatal injury       148
# Name: count, dtype: int64

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
sc

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Day_of_week'], bins=5, kde=True)
plt.title('Number of accedint')
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# ###Insights and Conclusions
#
# *Cleaning data take most of the work time and cleaning depends on the research goal sometimes you cant drop or delete some data because it the main core of the analisys*
#
# age 18-30 has done most of the accidnts , fetal injures is high for the number of data given, serios injury more likely to happen on Sunday and tuesday
